# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
from torch.optim import Adam
import torchvision.transforms.functional as fn

import os
import time
import math
import numpy as np
import matplotlib.pyplot as plt

from di_dataset import DepthImageDataset

from torch.utils.tensorboard import SummaryWriter

# %%
writer = SummaryWriter('runs/vae_cifar10')

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# 2022-02-23 18:37:36.279767: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# cpu
# /home/patricknit/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/torch/cuda/__init__.py:80: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 10010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:112.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# # Load Dataset

# %%
saves_folders = "../../../rl_data"
load_paths = [os.path.join(saves_folders, saves_folder) for saves_folder in os.listdir(saves_folders)]

# %%
load_path = "../../../rl_data/saves_2"

# %%
# Hyperparams
latent_dim = 800 
num_epochs = 120
batch_size = 1
learning_rate = 1e-3

# %%
# Obtain train and test data
dataset = DepthImageDataset(load_path=load_path) # Can only do 1 pickle file for now
# Out:
# Loading from ../../../rl_data/saves_2
# 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.82it/s]

# %%
train_size = int(0.9 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, num_workers=0)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, num_workers=0)
len(train_loader), len(test_loader), len(train_dataset), len(test_dataset)
# Out:
# (1, 1, 1, 1)

# %%
dataiter = iter(train_loader)
image_batch = dataiter.next()

def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

for image in image_batch:
    imshow(image)
    
image.shape
# Out:
# torch.Size([1, 272, 480])

# %%
image_batch.squeeze().mean(), image_batch.squeeze().var()
# Out:
# (tensor(0.7420), tensor(0.0769))

# %% [markdown]
# # Define Variational Autoencoder

# %%
class VAE(nn.Module):
    def __init__(self, input_channels, feature_dim=31*57, latent_dim=500) -> None:
        super(VAE, self).__init__()
        # (input width - filter size + 2*padding)/stride + 1
        self.encoder = nn.Sequential(
            nn.Conv2d(input_channels, 16, kernel_size=5, stride=2),
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=5, stride=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=5, stride=2),
            nn.ReLU()
        )
        
        self.fc_mu = nn.Linear(64*feature_dim, latent_dim)
        self.fc_logvar = nn.Linear(64*feature_dim, latent_dim)
        
        self.fc_z = nn.Linear(latent_dim, 64*feature_dim)
        
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size=5, stride=2),
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=5, stride=2, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(16, input_channels, kernel_size=5, stride=2, output_padding=1),
            nn.ReLU(),
            nn.Sigmoid()
        )

    def forward(self, x):
        # Inference
        x_enc = self.encoder(x)
        x_enc = x_enc.view(-1, 64*31*57)
        
        mu = self.fc_mu(x_enc)
        logvar = self.fc_logvar(x_enc)

        # Reparametrisation
        std = torch.exp(logvar/2)
        epsilon = torch.randn_like(std) # generate eps [0,1) with dim matching std
        z = mu + std * epsilon

        # Generate
        x_hat = self.fc_z(z)
        x_hat = x_hat.view(-1, 64, 31, 57)
        x_hat = self.decoder(x_hat)
        
        return mu, logvar, x_hat
    
vae_model = VAE(input_channels=1, latent_dim=latent_dim)

# %%
from torchsummary import summary
summary(vae_model, (1, 272, 480))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 134, 238]             416
#               ReLU-2         [-1, 16, 134, 238]               0
#             Conv2d-3          [-1, 32, 65, 117]          12,832
#               ReLU-4          [-1, 32, 65, 117]               0
#             Conv2d-5           [-1, 64, 31, 57]          51,264
#               ReLU-6           [-1, 64, 31, 57]               0
#             Linear-7                  [-1, 500]      56,544,500
#             Linear-8                  [-1, 500]      56,544,500
#             Linear-9               [-1, 113088]      56,657,088
#   ConvTranspose2d-10          [-1, 32, 65, 117]          51,232
#              ReLU-11          [-1, 32, 65, 117]               0
#   ConvTranspose2d-12         [-1, 16, 134, 238]          12,816
#              ReLU-13         [-1, 16, 134, 238]               0
#   ConvTranspose2d-14          [-1, 1, 272, 480]             401
#              ReLU-15          [-1, 1, 272, 480]               0
#           Sigmoid-16          [-1, 1, 272, 480]               0
# ================================================================
# Total params: 169,875,049
# Trainable params: 169,875,049
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.50
# Forward/backward pass size (MB): 28.58
# Params size (MB): 648.02
# Estimated Total Size (MB): 677.10
# ----------------------------------------------------------------

# %% [markdown]
# # Training

# %%
def loss_function(x, x_hat, mean, log_var):
    #reproduction_loss = nn.BCELoss(reduction='sum')(x_hat, x)
    reproduction_loss = F.binary_cross_entropy(x_hat, x, reduction="sum")
    KLD      = 0.5 * torch.sum(1+ log_var - mean.pow(2) - log_var.exp())

    return reproduction_loss - KLD

# %%
# def loss_function(x, x_hat, mu, logvar):
#     reproduction_loss = F.mse_loss(x_hat, x, reduction="sum")
#     kl_divergence = 0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

#     return reproduction_loss - kl_divergence

# %%
n_training_samples = len(train_dataset)
n_iterations = math.ceil(n_training_samples/batch_size)
n_training_samples, n_iterations
# Out:
# (1, 1)

# %%
vae_model = VAE(input_channels=1, latent_dim=latent_dim)
optimiser = torch.optim.Adam(vae_model.parameters(), lr=learning_rate)

# %%
for epoch in range(num_epochs):
    overall_loss = 0
    since = time.time()
    for i, image in enumerate(train_loader):

        optimiser.zero_grad()

        # VAE forward pass
        mu, logvar, x_hat = vae_model(image)

        # Loss
        loss = loss_function(image, x_hat, mu, logvar)

        overall_loss += loss

        # Update weights
        loss.backward()
        optimiser.step()

        if (i+1) % 1 == 0:
            time_elapsed = time.time() - since
            #print(f"epoch: {epoch+1}/{num_epochs}, step: {i+1}/{n_iterations}, image: {image.shape}")
            print(f"epoch: {epoch+1}/{num_epochs}, step: {i+1}/{n_iterations}, Avg loss: {overall_loss/((i+1)*batch_size):.3f}, time: {time_elapsed:.3f}")
# Out:
# epoch: 1/120, step: 1/1, Avg loss: 85126.578, time: 1.335
# epoch: 2/120, step: 1/1, Avg loss: 87984.117, time: 1.457
# epoch: 3/120, step: 1/1, Avg loss: 84307.734, time: 1.572
# epoch: 4/120, step: 1/1, Avg loss: 83954.117, time: 1.583
# epoch: 5/120, step: 1/1, Avg loss: 83491.922, time: 1.608
# epoch: 6/120, step: 1/1, Avg loss: 83084.672, time: 1.945
# epoch: 7/120, step: 1/1, Avg loss: 81839.688, time: 2.363
# epoch: 8/120, step: 1/1, Avg loss: 76648.891, time: 2.138
# epoch: 9/120, step: 1/1, Avg loss: 73016.586, time: 2.496
# epoch: 10/120, step: 1/1, Avg loss: 70933.703, time: 2.246
# epoch: 11/120, step: 1/1, Avg loss: 65574.266, time: 2.455
# epoch: 12/120, step: 1/1, Avg loss: 62592.457, time: 2.169
# epoch: 13/120, step: 1/1, Avg loss: 60820.406, time: 2.069
# epoch: 14/120, step: 1/1, Avg loss: 59652.945, time: 2.205
# epoch: 15/120, step: 1/1, Avg loss: 62364.184, time: 1.945
# epoch: 16/120, step: 1/1, Avg loss: 61700.246, time: 2.108
# epoch: 17/120, step: 1/1, Avg loss: 59900.527, time: 2.083
# epoch: 18/120, step: 1/1, Avg loss: 57788.434, time: 1.979
# epoch: 19/120, step: 1/1, Avg loss: 57218.012, time: 2.199
# epoch: 20/120, step: 1/1, Avg loss: 57029.070, time: 1.780
# epoch: 21/120, step: 1/1, Avg loss: 57240.855, time: 2.109
# epoch: 22/120, step: 1/1, Avg loss: 56623.586, time: 2.027
# epoch: 23/120, step: 1/1, Avg loss: 56933.434, time: 2.037
# epoch: 24/120, step: 1/1, Avg loss: 56378.602, time: 2.011
# epoch: 25/120, step: 1/1, Avg loss: 56996.645, time: 1.775
# epoch: 26/120, step: 1/1, Avg loss: 56391.262, time: 2.081
# epoch: 27/120, step: 1/1, Avg loss: 56127.652, time: 2.005
# epoch: 28/120, step: 1/1, Avg loss: 56022.941, time: 2.195
# epoch: 29/120, step: 1/1, Avg loss: 55996.918, time: 2.135
# epoch: 30/120, step: 1/1, Avg loss: 55934.016, time: 1.764
# epoch: 31/120, step: 1/1, Avg loss: 55870.395, time: 2.492
# epoch: 32/120, step: 1/1, Avg loss: 55780.742, time: 1.861
# epoch: 33/120, step: 1/1, Avg loss: 55512.461, time: 2.084
# epoch: 34/120, step: 1/1, Avg loss: 55874.488, time: 1.826
# epoch: 35/120, step: 1/1, Avg loss: 55434.332, time: 2.110
# epoch: 36/120, step: 1/1, Avg loss: 55169.906, time: 2.006
# epoch: 37/120, step: 1/1, Avg loss: 55145.234, time: 1.955
# epoch: 38/120, step: 1/1, Avg loss: 55549.844, time: 2.043
# epoch: 39/120, step: 1/1, Avg loss: 54596.543, time: 2.045
# epoch: 40/120, step: 1/1, Avg loss: 54185.535, time: 2.087
# epoch: 41/120, step: 1/1, Avg loss: 53172.156, time: 2.050
# epoch: 42/120, step: 1/1, Avg loss: 52772.355, time: 1.881
# epoch: 43/120, step: 1/1, Avg loss: 52669.883, time: 2.118
# epoch: 44/120, step: 1/1, Avg loss: 52435.215, time: 1.789
# epoch: 45/120, step: 1/1, Avg loss: 51564.789, time: 2.112
# epoch: 46/120, step: 1/1, Avg loss: 51042.184, time: 1.965
# epoch: 47/120, step: 1/1, Avg loss: 50959.328, time: 2.028
# epoch: 48/120, step: 1/1, Avg loss: 50762.504, time: 2.204
# epoch: 49/120, step: 1/1, Avg loss: 50467.715, time: 1.780
# epoch: 50/120, step: 1/1, Avg loss: 50434.109, time: 2.054
# epoch: 51/120, step: 1/1, Avg loss: 50513.570, time: 1.787
# epoch: 52/120, step: 1/1, Avg loss: 50205.293, time: 2.027
# epoch: 53/120, step: 1/1, Avg loss: 50198.738, time: 1.848
# epoch: 54/120, step: 1/1, Avg loss: 50353.996, time: 1.924
# epoch: 55/120, step: 1/1, Avg loss: 50217.105, time: 2.038
# epoch: 56/120, step: 1/1, Avg loss: 49987.715, time: 1.835
# epoch: 57/120, step: 1/1, Avg loss: 50244.633, time: 2.097
# epoch: 58/120, step: 1/1, Avg loss: 50317.480, time: 1.737
# epoch: 59/120, step: 1/1, Avg loss: 51398.223, time: 2.129
# epoch: 60/120, step: 1/1, Avg loss: 49892.176, time: 1.947
# epoch: 61/120, step: 1/1, Avg loss: 49943.418, time: 1.901
# epoch: 62/120, step: 1/1, Avg loss: 50181.668, time: 2.142
# epoch: 63/120, step: 1/1, Avg loss: 50270.500, time: 1.776
# epoch: 64/120, step: 1/1, Avg loss: 50818.789, time: 2.084
# epoch: 65/120, step: 1/1, Avg loss: 49775.062, time: 1.885
# epoch: 66/120, step: 1/1, Avg loss: 49815.102, time: 2.021
# epoch: 67/120, step: 1/1, Avg loss: 49820.762, time: 2.134
# epoch: 68/120, step: 1/1, Avg loss: 50979.609, time: 1.806
# epoch: 69/120, step: 1/1, Avg loss: 49682.258, time: 2.146
# epoch: 70/120, step: 1/1, Avg loss: 49660.871, time: 1.692
# epoch: 71/120, step: 1/1, Avg loss: 49988.184, time: 2.093
# epoch: 72/120, step: 1/1, Avg loss: 49715.496, time: 1.874
# epoch: 73/120, step: 1/1, Avg loss: 50097.621, time: 1.934
# epoch: 74/120, step: 1/1, Avg loss: 49687.961, time: 2.092
# epoch: 75/120, step: 1/1, Avg loss: 49999.625, time: 1.780
# epoch: 76/120, step: 1/1, Avg loss: 51469.609, time: 2.181
# epoch: 77/120, step: 1/1, Avg loss: 50067.816, time: 1.895
# epoch: 78/120, step: 1/1, Avg loss: 49772.309, time: 1.928
# epoch: 79/120, step: 1/1, Avg loss: 49459.285, time: 2.112
# epoch: 80/120, step: 1/1, Avg loss: 53281.285, time: 1.725
# epoch: 81/120, step: 1/1, Avg loss: 50178.348, time: 2.033
# epoch: 82/120, step: 1/1, Avg loss: 50121.855, time: 1.814
# epoch: 83/120, step: 1/1, Avg loss: 49486.418, time: 2.074
# epoch: 84/120, step: 1/1, Avg loss: 49809.906, time: 2.011
# epoch: 85/120, step: 1/1, Avg loss: 49972.645, time: 1.891
# epoch: 86/120, step: 1/1, Avg loss: 50172.832, time: 2.088
# epoch: 87/120, step: 1/1, Avg loss: 50308.598, time: 1.895
# epoch: 88/120, step: 1/1, Avg loss: 49560.035, time: 2.003
# epoch: 89/120, step: 1/1, Avg loss: 49905.207, time: 2.010
# epoch: 90/120, step: 1/1, Avg loss: 49344.480, time: 1.751
# epoch: 91/120, step: 1/1, Avg loss: 49450.535, time: 2.132
# epoch: 92/120, step: 1/1, Avg loss: 49305.812, time: 1.788
# epoch: 93/120, step: 1/1, Avg loss: 50027.496, time: 2.077
# epoch: 94/120, step: 1/1, Avg loss: 49343.922, time: 1.955
# epoch: 95/120, step: 1/1, Avg loss: 49505.816, time: 1.909
# epoch: 96/120, step: 1/1, Avg loss: 49201.652, time: 2.052
# epoch: 97/120, step: 1/1, Avg loss: 49302.559, time: 1.916
# epoch: 98/120, step: 1/1, Avg loss: 49779.270, time: 2.128
# epoch: 99/120, step: 1/1, Avg loss: 50027.371, time: 1.897
# epoch: 100/120, step: 1/1, Avg loss: 49158.273, time: 1.905
# epoch: 101/120, step: 1/1, Avg loss: 49228.926, time: 2.164
# epoch: 102/120, step: 1/1, Avg loss: 49493.270, time: 1.774
# epoch: 103/120, step: 1/1, Avg loss: 49027.051, time: 2.139
# epoch: 104/120, step: 1/1, Avg loss: 49429.910, time: 1.983
# epoch: 105/120, step: 1/1, Avg loss: 49015.004, time: 1.892
# epoch: 106/120, step: 1/1, Avg loss: 49142.293, time: 1.988
# epoch: 107/120, step: 1/1, Avg loss: 49012.062, time: 1.892
# epoch: 108/120, step: 1/1, Avg loss: 49704.895, time: 2.099
# epoch: 109/120, step: 1/1, Avg loss: 49205.660, time: 1.836
# epoch: 110/120, step: 1/1, Avg loss: 49766.277, time: 2.068
# epoch: 111/120, step: 1/1, Avg loss: 48758.758, time: 2.059
# epoch: 112/120, step: 1/1, Avg loss: 48942.746, time: 1.865
# epoch: 113/120, step: 1/1, Avg loss: 48602.488, time: 2.044
# epoch: 114/120, step: 1/1, Avg loss: 48993.570, time: 1.821
# epoch: 115/120, step: 1/1, Avg loss: 48435.621, time: 2.161
# epoch: 116/120, step: 1/1, Avg loss: 48295.281, time: 1.942
# epoch: 117/120, step: 1/1, Avg loss: 48996.207, time: 1.856
# epoch: 118/120, step: 1/1, Avg loss: 48348.812, time: 2.149
# epoch: 119/120, step: 1/1, Avg loss: 48155.656, time: 1.776
# epoch: 120/120, step: 1/1, Avg loss: 48704.648, time: 2.089

# %% [markdown]
# # Evaluate
#
# ## Test set

# %%
vae_model.eval()
# Visualise sample of images

with torch.no_grad():
    for images in test_loader:
        # VAE forward pass
        _, _, x_hat = vae_model(images)

        print(images.mean(), x_hat.mean())
        print(images.var(), x_hat.var())
        print(images.shape)
        for idx in range(1):
            # show images
            imshow(images[idx])
            imshow(x_hat[idx])

        # write to tensorboard
        # writer.add_image('four_cifar10_images', inv_normalize(img_grid))
# Out:
# tensor(0.7420) tensor(0.7902)
# tensor(0.0769) tensor(0.0489)
# torch.Size([1, 1, 272, 480])

# %% [markdown]
# ## Training set

# %%
vae_model.eval()
# Visualise sample of images
with torch.no_grad():
    for images in train_loader:
        # VAE forward pass
        _, _, x_hat = vae_model(images)

        print(images.mean(), x_hat.mean())
        print(images.var(), x_hat.var())
        print(images.shape)
        for idx in range(1):
            # show images
            imshow(images[idx])
            imshow(x_hat[idx])
# Out:
# tensor(0.7420) tensor(0.7877)
# tensor(0.0769) tensor(0.0487)
# torch.Size([1, 1, 272, 480])
