# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision

import time
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
from torchsummary import summary
from collections import deque

from di_dataset3 import DepthImageDataset, collate_batch

from torch.utils.tensorboard import SummaryWriter
# Out:
# 2022-03-15 16:37:40.824720: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/ros/noetic/lib:/home/patricknit/.mujoco/mjpro150/bin
# 2022-03-15 16:37:40.824739: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/patricknit/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/torch/cuda/__init__.py:80: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 10010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:112.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Hyperparams

# %%
LINUX = True

latent_dim = 64
num_epochs = 250
batch_size = 32
learning_rate = 1e-3

save_model = True
load_model = False

if LINUX:
    base_path = "/home/patricknit"
else:
    base_path = "/Users/patricknitschke/Library/CloudStorage/OneDrive-NTNU/NTNU/Kybernetikk og robotikk/Master/Thesis/Code"

tfrecord_folder = base_path + "/rl_data/tfrecord_wfiltered"
tfrecord_test_folder = tfrecord_folder + "/test"

save_model_file = base_path + "/vae_models/dronet_final_64_sum_old_weight"
load_model_file = base_path + "/vae_models/vae_dronet_sigmoid_MSE_weighted_filtered_140.pth"

writer = SummaryWriter('runs'+save_model_file[save_model_file.rfind("/"):])

# %% [markdown]
# # Load Dataset

# %%
train_dataset = DepthImageDataset(tfrecord_folder=tfrecord_folder, batch_size=batch_size, one_tfrecord=True) # 180 tfrecords
test_dataset = DepthImageDataset(tfrecord_folder=tfrecord_test_folder, batch_size=batch_size, one_tfrecord=True) # 20 tfrecords

len_train_dataset, len_test_dataset = len(train_dataset), len(test_dataset)
n_training_samples = len_train_dataset * 32 # 32 samples per batch
print(len_train_dataset, len_test_dataset)

train_loader = DataLoader(dataset=train_dataset, batch_size=1, collate_fn=collate_batch)
test_loader = DataLoader(dataset=test_dataset, batch_size=1, collate_fn=collate_batch)

images, images_filtered, *_ = next(iter(train_loader)) # image, filtered image, height, width, depth
images.shape, images_filtered.shape
# Out:
# 2022-03-15 16:37:42.416855: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-15 16:37:42.416892: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (patricknit-OptiPlex-7060): /proc/driver/nvidia/version does not exist
# 2022-03-15 16:37:42.417901: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data98.tfrecords']
# Iterating length... 	Done: 63
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data183.tfrecords']
# Iterating length... 	Done: 70
# 63 70

# %%
def imshow(image):
    io.imshow(image.squeeze().numpy())
    io.show()

def make_grid_for_tensorboard(images_list, n_grids=2):
    joined_images = []
    [joined_images.extend(images[:n_grids]) for images in images_list]
    return torchvision.utils.make_grid(joined_images, nrow=1, padding=5)

def gridshow(images_list, n_grids=None):
    for n, items in enumerate(zip(*images_list)):
        grid = torchvision.utils.make_grid([*items], nrow=1, padding=5).permute(1, 2, 0)
        imshow(grid)
        if (n+1) == n_grids:
            return

gridshow([images, images_filtered], n_grids=4)
#imshow(make_grid_for_tensorboard([images, images_filtered]).permute(1,2,0))

# %% [markdown]
# # Define Variational Autoencoder
#
# Adapted from https://github.com/microsoft/AirSim-Drone-Racing-VAE-Imitation/blob/master/racing_models/cmvae.py

# %% [markdown]
# ### Dronet
# ResNet8 as encoder.

# %%
class Dronet(nn.Module):
    def __init__(self, input_dim, num_outputs):
        super(Dronet, self).__init__()
        
        print('[Dronet] Starting dronet')

        self.bn0 = nn.BatchNorm2d(32)
        self.bn1 = nn.BatchNorm2d(32)
        self.bn2 = nn.BatchNorm2d(32)
        self.bn3 = nn.BatchNorm2d(64)
        self.bn4 = nn.BatchNorm2d(64)
        self.bn5 = nn.BatchNorm2d(128)
        self.bn6 = nn.BatchNorm2d(128)

        self.conv0 = nn.Conv2d(input_dim, 32, kernel_size=5, stride=2, padding=2)
        self.xavier_uniform_init(self.conv0)
        
        self.conv0_2 = nn.Conv2d(32, 32, kernel_size=5, stride=2, padding=2)

        self.conv1 = nn.Conv2d(32, 32, kernel_size=3, stride=2, padding=1) 
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=1, stride=2)
        self.xavier_uniform_init(self.conv3)

        self.conv4 = nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1)
        self.conv5 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.conv6 = nn.Conv2d(32, 64, kernel_size=1, stride=2)
        self.xavier_uniform_init(self.conv6)

        self.conv7 = nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1)
        self.conv8 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
        self.conv9 = nn.Conv2d(64, 128, kernel_size=1, stride=2)
        self.xavier_uniform_init(self.conv9)

        self.dense0 = nn.Linear(9*15*128, 64) # Todo: check size
        self.dense1 = nn.Linear(64, num_outputs)

        print('[Dronet] Done with dronet')
    
    
    def xavier_uniform_init(self, m):
        """
        Default initialisation in Keras is glorot_uniform == xavier_uniform in Pytorch

        https://discuss.pytorch.org/t/crossentropyloss-expected-object-of-type-torch-longtensor/28683/6?u=ptrblck
        https://stackoverflow.com/questions/49433936/how-to-initialize-weights-in-pytorch
        """
        if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight, gain=nn.init.calculate_gain('linear')) # gain=nn.init.calculate_gain('relu')
            nn.init.zeros_(m.bias)
        return m

    def forward(self, img):
        # Input
        
        x1 = self.conv0(img)
        #x1, indices = self.max0(x1)
        x1 = self.conv0_2(x1)

        # First residual block
        x2 = self.bn0(x1)
        x2 = torch.relu(x2)
        x2 = self.conv1(x2)

        x2 = self.bn1(x2)
        x2 = torch.relu(x2)
        x2 = self.conv2(x2)
        
        x1 = self.conv3(x1)
        x3 = x1+x2

        # Second residual block
        x4 = self.bn2(x3)
        # x4 = x3
        x4 = torch.relu(x4)
        x4 = self.conv4(x4)

        x4 = self.bn3(x4)
        x4 = torch.relu(x4)
        x4 = self.conv5(x4)
        
        x3 = self.conv6(x3)
        x5 = x3+x4 # 34, 60, 64

        # Third residual block
        x6 = self.bn4(x5)
        x6 = torch.relu(x6)
        x6 = self.conv7(x6)

        x6 = self.bn5(x6)
        x6 = torch.relu(x6)
        x6 = self.conv8(x6)

        x5 = self.conv9(x5)
        x7 = x5+x6 # 17, 30, 128
        
        x = x7.view(x7.size(0), 9*15*128)

        x = torch.relu(x)
        x = self.dense0(x)
        x = torch.relu(x)        
        x_enc = self.dense1(x)
        return x_enc

dronet = Dronet(input_dim=1, num_outputs=latent_dim*2)
summary(dronet, input_size=(1, 270, 480), batch_size=-1, device=device.type)

class ImgDecoder(nn.Module):
    def __init__(self, input_dim=100, batch=32):
        super(ImgDecoder, self).__init__()
        print('[ImgDecoder] Starting create_model')
        self.dense = nn.Linear(input_dim, 9*15*128)
        
        self.bn0 = nn.BatchNorm2d(128)
        self.bn1 = nn.BatchNorm2d(128)
        self.bn2 = nn.BatchNorm2d(64)
        self.bn3 = nn.BatchNorm2d(64)
        self.bn4 = nn.BatchNorm2d(32)
        self.bn5 = nn.BatchNorm2d(32)
        self.bn6 = nn.BatchNorm2d(16)
        
        self.deconv1 = nn.ConvTranspose2d(128, 128, kernel_size=3, stride=1, padding=1)
        self.deconv2 = nn.ConvTranspose2d(128, 64, kernel_size=5, stride=2, padding=(2,2), output_padding=(0,1), dilation=1)
        self.deconv3 = nn.ConvTranspose2d(64, 64, kernel_size=6, stride=2, padding=(2,2), output_padding=(0,0), dilation=1)
        self.deconv4 = nn.ConvTranspose2d(64, 32, kernel_size=6, stride=2, padding=(2,2), output_padding=(0,0), dilation=1)
        self.deconv5 = nn.ConvTranspose2d(32, 32, kernel_size=5, stride=2, padding=(2,2), output_padding=(0,1), dilation=1)
        self.deconv6 = nn.ConvTranspose2d(32, 16, kernel_size=6, stride=2, padding=(2,2), output_padding=(0,0))
        self.deconv7 = nn.ConvTranspose2d(16, 1, kernel_size=5, stride=1, padding=2) # tanh activation or sigmoid

        print('[ImgDecoder] Done with create_model')

    def forward(self, z):
        x = self.dense(z)
        x = x.view(x.size(0), 128, 9, 15)
        
        x = self.deconv1(x)
#         x = self.bn1(x)
        x = torch.relu(x)
        
        x = self.deconv2(x)
#         x = self.bn2(x)
        x = torch.relu(x)
        
        x = self.deconv3(x)
#         x = self.bn3(x)
        x = torch.relu(x)

        x = self.deconv4(x)
#         x = self.bn4(x)
        x = torch.relu(x)

        x = self.deconv5(x)
#         x = self.bn5(x)
        #x = self.unpool(x, indices, output_size=(x.size(0), 1, 135, 240))
        x = torch.relu(x)
        
        x = self.deconv6(x)
#         x = self.bn6(x)
        x = torch.relu(x)

        x = self.deconv7(x)
        x = torch.sigmoid(x)
        return x

img_decoder = ImgDecoder(input_dim=latent_dim, batch=1)
summary(img_decoder, (1,latent_dim))

class Lambda(nn.Module):
    def __init__(self, func):
        super(Lambda, self).__init__()
        self.func = func
        
    def forward(self, x):
        return self.func(x)
        

class VAE(nn.Module):
    def __init__(self, n_z):
        super(VAE, self).__init__()
        
        # create the 3 base models:
        self.q_img = Dronet(input_dim=1, num_outputs=n_z*2)
        self.p_img = ImgDecoder(input_dim=n_z)
        
        # Create sampler
        self.mean_params = Lambda(lambda x: x[:, :n_z])
        self.logvar_params = Lambda(lambda x: x[:, n_z:])

    def forward(self, x):

        x = self.q_img(x)
        
        means = self.mean_params(x)
        logvar = self.logvar_params(x)
        stddev = torch.exp(0.5 * logvar)
        eps = torch.randn_like(stddev)
        z = means + eps * stddev

        img_recon = self.p_img(z)
        
        return img_recon, means, logvar, z
    
    def forward_test(self, x):
        x = self.q_img(x)
        
        means = self.mean_params(x)
        logvar = self.logvar_params(x)
        stddev = torch.exp(0.5 * logvar)
        eps = torch.zeros_like(stddev)
        z = means + eps * stddev

        img_recon = self.p_img(z)
        return img_recon, means, logvar, z
        

    def encode(self, x):
        x = self.q_img(x)
        means = self.mean_params(x)
        stddev = torch.exp(0.5 * self.stddev_params(x))
        eps = torch.randn_like(stddev)
        z = means + eps * stddev
        return z, means, stddev

    def decode(self, z, mode):
        img_recon = self.p_img(z)
        return img_recon
# Out:
# [Dronet] Starting dronet
# [Dronet] Done with dronet
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 135, 240]             832
#             Conv2d-2          [-1, 32, 68, 120]          25,632
#        BatchNorm2d-3          [-1, 32, 68, 120]              64
#             Conv2d-4           [-1, 32, 34, 60]           9,248
#        BatchNorm2d-5           [-1, 32, 34, 60]              64
#             Conv2d-6           [-1, 32, 34, 60]           9,248
#             Conv2d-7           [-1, 32, 34, 60]           1,056
#        BatchNorm2d-8           [-1, 32, 34, 60]              64
#             Conv2d-9           [-1, 64, 17, 30]          18,496
#       BatchNorm2d-10           [-1, 64, 17, 30]             128
#            Conv2d-11           [-1, 64, 17, 30]          36,928
#            Conv2d-12           [-1, 64, 17, 30]           2,112
#       BatchNorm2d-13           [-1, 64, 17, 30]             128
#            Conv2d-14           [-1, 128, 9, 15]          73,856
#       BatchNorm2d-15           [-1, 128, 9, 15]             256
#            Conv2d-16           [-1, 128, 9, 15]         147,584
#            Conv2d-17           [-1, 128, 9, 15]           8,320
#            Linear-18                   [-1, 64]       1,105,984
#            Linear-19                  [-1, 128]           8,320
# ================================================================
# Total params: 1,448,320
# Trainable params: 1,448,320
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.49
# Forward/backward pass size (MB): 16.16
# Params size (MB): 5.52
# Estimated Total Size (MB): 22.18
# ----------------------------------------------------------------
# [ImgDecoder] Starting create_model
# [ImgDecoder] Done with create_model
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1             [-1, 1, 17280]       1,123,200
#    ConvTranspose2d-2           [-1, 128, 9, 15]         147,584
#    ConvTranspose2d-3           [-1, 64, 17, 30]         204,864
#    ConvTranspose2d-4           [-1, 64, 34, 60]         147,520
#    ConvTranspose2d-5          [-1, 32, 68, 120]          73,760
#    ConvTranspose2d-6         [-1, 32, 135, 240]          25,632
#    ConvTranspose2d-7         [-1, 16, 270, 480]          18,448
#    ConvTranspose2d-8          [-1, 1, 270, 480]             401
# ================================================================
# Total params: 1,741,409
# Trainable params: 1,741,409
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 28.22
# Params size (MB): 6.64
# Estimated Total Size (MB): 34.86
# ----------------------------------------------------------------

# %% [markdown]
# ### Define Model

# %%
vae_model = VAE(n_z=latent_dim).to(device)
writer.add_graph(vae_model, images)

if load_model:
    vae_model.load_state_dict(torch.load(load_model_file))
    print(f"Loaded model: {load_model_file}")

optimiser = torch.optim.Adam(vae_model.parameters(), lr=learning_rate)
summary(vae_model, (1, 270, 480))
# Out:
# [Dronet] Starting dronet
# [Dronet] Done with dronet
# [ImgDecoder] Starting create_model
# [ImgDecoder] Done with create_model
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 135, 240]             832
#             Conv2d-2          [-1, 32, 68, 120]          25,632
#        BatchNorm2d-3          [-1, 32, 68, 120]              64
#             Conv2d-4           [-1, 32, 34, 60]           9,248
#        BatchNorm2d-5           [-1, 32, 34, 60]              64
#             Conv2d-6           [-1, 32, 34, 60]           9,248
#             Conv2d-7           [-1, 32, 34, 60]           1,056
#        BatchNorm2d-8           [-1, 32, 34, 60]              64
#             Conv2d-9           [-1, 64, 17, 30]          18,496
#       BatchNorm2d-10           [-1, 64, 17, 30]             128
#            Conv2d-11           [-1, 64, 17, 30]          36,928
#            Conv2d-12           [-1, 64, 17, 30]           2,112
#       BatchNorm2d-13           [-1, 64, 17, 30]             128
#            Conv2d-14           [-1, 128, 9, 15]          73,856
#       BatchNorm2d-15           [-1, 128, 9, 15]             256
#            Conv2d-16           [-1, 128, 9, 15]         147,584
#            Conv2d-17           [-1, 128, 9, 15]           8,320
#            Linear-18                   [-1, 64]       1,105,984
#            Linear-19                  [-1, 128]           8,320
#            Dronet-20                  [-1, 128]               0
#            Lambda-21                   [-1, 64]               0
#            Lambda-22                   [-1, 64]               0
#            Linear-23                [-1, 17280]       1,123,200
#   ConvTranspose2d-24           [-1, 128, 9, 15]         147,584
#   ConvTranspose2d-25           [-1, 64, 17, 30]         204,864
#   ConvTranspose2d-26           [-1, 64, 34, 60]         147,520
#   ConvTranspose2d-27          [-1, 32, 68, 120]          73,760
#   ConvTranspose2d-28         [-1, 32, 135, 240]          25,632
#   ConvTranspose2d-29         [-1, 16, 270, 480]          18,448
#   ConvTranspose2d-30          [-1, 1, 270, 480]             401
#        ImgDecoder-31          [-1, 1, 270, 480]               0
# ================================================================
# Total params: 3,189,729
# Trainable params: 3,189,729
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.49
# Forward/backward pass size (MB): 45.37
# Params size (MB): 12.17
# Estimated Total Size (MB): 58.03
# ----------------------------------------------------------------
# /home/patricknit/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/torch/jit/_trace.py:983: TracerWarning: Trace had nondeterministic nodes. Did you forget call .eval() on your model? Nodes:
# 	%eps : Float(32, 64, strides=[64, 1], requires_grad=0, device=cpu) = aten::randn_like(%stddev, %523, %524, %525, %526, %527) # /tmp/ipykernel_4005355/3683525493.py:29:0
# This may cause errors in trace checking. To disable trace checking, pass check_trace=False to torch.jit.trace()
#   _check_trace(
# /home/patricknit/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/torch/jit/_trace.py:983: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Tensor-likes are not close!
#
# Mismatched elements: 3477465 / 4147200 (83.9%)
# Greatest absolute difference: 0.000496983528137207 at index (12, 0, 118, 109) (up to 1e-05 allowed)
# Greatest relative difference: 0.0008973677356585827 at index (12, 0, 118, 109) (up to 1e-05 allowed)
#   _check_trace(
# /home/patricknit/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/torch/jit/_trace.py:983: TracerWarning: Output nr 4. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Tensor-likes are not close!
#
# Mismatched elements: 2048 / 2048 (100.0%)
# Greatest absolute difference: 5.206382513046265 at index (16, 10) (up to 1e-05 allowed)
# Greatest relative difference: 826.3419436746951 at index (2, 61) (up to 1e-05 allowed)
#   _check_trace(

# %% [markdown]
# # Training

# %%
def depth_gain(x):
    return np.minimum(1/(x + 0.5) - 0.5, 1*np.ones_like(x))

x = np.arange(0, 1.001, 0.001)
y = depth_gain(x)

plt.figure(figsize=(4, 4))
plt.plot(x, y)
plt.grid()
plt.legend(["depth gain per pixel value"])
plt.show()

# %%
def BCELoss(x, x_hat, mean, log_var):
    reproduction_loss = nn.BCELoss(reduction='mean')(x_hat, x) * (270 * 480)
    KLD      = 0.5 * torch.sum(1+ log_var - mean.pow(2) - log_var.exp())

    return reproduction_loss - KLD

def MSE(x, x_hat, mu, logvar):
    reproduction_loss = F.mse_loss(x_hat, x, reduction="mean") * (270 * 480)
    kl_divergence = 0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

    return reproduction_loss - kl_divergence

def weighted_MSE(x, x_hat, mu, logvar):
    reproduction_loss = (depth_gain(x) * torch.square(x_hat - x)).sum() # Old version, reduce by mean later
    kl_divergence = 0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    return reproduction_loss - kl_divergence

def filtered_weighted_MSE(filtered_x, x_hat, mu, logvar): 
    reproduction_loss = (depth_gain(filtered_x) * torch.square(x_hat - filtered_x)).sum() # change later to mean
    kl_divergence = 0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    return reproduction_loss - kl_divergence

# %%
time_iteration = deque(maxlen=100)
total_train_iterations = 0
total_test_iterations = 0

if load_model:
    start = load_model_file.rfind("_") + 1
    end = load_model_file.rfind(".")
    epoch_start = int("".join([char for char in load_model_file[start:end]]))
    num_epochs = [epoch_start, num_epochs]
else:
    num_epochs = [num_epochs]
    
for epoch in range(*num_epochs):
    # Random file each time
    train_dataset = DepthImageDataset(tfrecord_folder=tfrecord_folder, batch_size=batch_size, one_tfrecord=True)
    train_loader = DataLoader(dataset=train_dataset, batch_size=1, collate_fn=collate_batch)
    train_iterations = len(train_loader)

    test_dataset = DepthImageDataset(tfrecord_folder=tfrecord_test_folder, batch_size=batch_size, one_tfrecord=True)
    test_loader = DataLoader(dataset=test_dataset, batch_size=1, collate_fn=collate_batch)
    test_iterations = len(test_loader)
    
    print("Training...")
    vae_model.train()
    running_loss = 0.0
    since = time.time()
    for i, (image, image_filtered, *_) in enumerate(train_loader):
        since_iter = time.time() 
        optimiser.zero_grad()
        
        image = image.to(device)
        image_filtered = image_filtered.to(device)

        # VAE forward pass
        x_hat, mu, logvar, z = vae_model(image)

        # Loss
        loss = filtered_weighted_MSE(image_filtered, x_hat, mu, logvar)
        running_loss += loss.item()

        # Update weights
        loss.backward()
        optimiser.step()

        time_iteration.append(time.time() - since_iter)
        iter_time_mean = np.array(time_iteration).mean()
    
        # Log info
        writer.add_scalar('training/loss', running_loss/((i+1)*batch_size), global_step=total_train_iterations)
        if (i+1) % (5) == 0:
            time_elapsed = time.time() - since
            print(f"Epoch: {epoch+1}/{num_epochs[-1]}, Step: {i+1}/{train_iterations}, Avg. train loss:", \
                  f"{running_loss/((i+1)*batch_size):.3f}, time: {time_elapsed:.2f}, Avg. per iter", \
                  f"{iter_time_mean:.2f}, Est. time left {iter_time_mean*(train_iterations - (i+1)):.2f}")
        if (i+1) % (5) == 0:
            grid = make_grid_for_tensorboard([image, image_filtered, x_hat], n_grids=1)
            writer.add_image('training/images', grid, global_step=total_train_iterations)
            
        total_train_iterations += 1
    
    print("Testing...")
    vae_model.eval()
    test_loss = 0.0
    since = time.time()
    for i, (image, image_filtered, *_) in enumerate(test_loader):
        since_iter = time.time() 
        optimiser.zero_grad()
        
        image = image.to(device)
        image_filtered = image_filtered.to(device)

        # VAE forward pass
        x_hat, mu, logvar, z = vae_model(image)

        # Loss
        loss = filtered_weighted_MSE(image_filtered, x_hat, mu, logvar)
        test_loss += loss.item()

        time_iteration.append(time.time() - since_iter)
        iter_time_mean = np.array(time_iteration).mean()
    
        # Log info
        writer.add_scalar('test/loss', test_loss/((i+1)*batch_size), global_step=total_test_iterations)
        if (i+1) % (5) == 0:
            time_elapsed = time.time() - since
            print(f"Epoch: {epoch+1}/{num_epochs[-1]}, Step: {i+1}/{test_iterations}, Avg. test loss:", \
                  f"{test_loss/((i+1)*batch_size):.3f}, time: {time_elapsed:.2f}, Avg. per iter", \
                  f"{iter_time_mean:.2f}, Est. time left {iter_time_mean*(test_iterations - (i+1)):.2f}")
            
        if (i+1) % (5) == 0:
            grid = make_grid_for_tensorboard([image, image_filtered, x_hat], n_grids=1)
            writer.add_image('test/images', grid, global_step=total_test_iterations)
            
        total_test_iterations += 1
    
    print(f"Epoch: {epoch+1}, Training loss: {running_loss/(train_iterations*batch_size):.3f}, Test loss: {test_loss/(test_iterations*batch_size):.3f}")
    writer.add_scalar('loss_per_epoch/train', running_loss/(train_iterations*batch_size), global_step=epoch)
    writer.add_scalar('loss_per_epoch/test', test_loss/(test_iterations*batch_size), global_step=epoch)

    
    # Save every 10 epochs
    if (epoch+1) % 10 == 0:
        save_model_file_dir = save_model_file + f"_{epoch+1}.pth"
        torch.save(vae_model.state_dict(), save_model_file_dir)
# Out:
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data18.tfrecords']
# Iterating length... 	Done: 66
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data180.tfrecords']
# Iterating length... 	Done: 64
# Training...
# gotcha
# Epoch: 1/250, Step: 5/66, Avg. train loss: 10235.510, time: 22.22, Avg. per iter 4.38, Est. time left 267.03
# Epoch: 1/250, Step: 10/66, Avg. train loss: 8630.730, time: 45.18, Avg. per iter 4.48, Est. time left 250.65
# Epoch: 1/250, Step: 15/66, Avg. train loss: 7372.062, time: 68.58, Avg. per iter 4.54, Est. time left 231.43
# Epoch: 1/250, Step: 20/66, Avg. train loss: 6582.264, time: 91.36, Avg. per iter 4.54, Est. time left 208.74
# Epoch: 1/250, Step: 25/66, Avg. train loss: 5958.883, time: 114.16, Avg. per iter 4.54, Est. time left 186.08
# Epoch: 1/250, Step: 30/66, Avg. train loss: 5593.362, time: 135.08, Avg. per iter 4.48, Est. time left 161.15
# Epoch: 1/250, Step: 35/66, Avg. train loss: 5388.762, time: 156.83, Avg. per iter 4.46, Est. time left 138.12
# Epoch: 1/250, Step: 40/66, Avg. train loss: 5205.181, time: 178.25, Avg. per iter 4.43, Est. time left 115.22
# Epoch: 1/250, Step: 45/66, Avg. train loss: 5014.992, time: 199.11, Avg. per iter 4.40, Est. time left 92.41
# Epoch: 1/250, Step: 50/66, Avg. train loss: 4842.351, time: 221.38, Avg. per iter 4.40, Est. time left 70.46
# Epoch: 1/250, Step: 55/66, Avg. train loss: 4694.218, time: 243.62, Avg. per iter 4.41, Est. time left 48.46
# Epoch: 1/250, Step: 60/66, Avg. train loss: 4558.164, time: 266.28, Avg. per iter 4.41, Est. time left 26.49
# Epoch: 1/250, Step: 65/66, Avg. train loss: 4427.082, time: 287.69, Avg. per iter 4.40, Est. time left 4.40
# Testing...
# gotcha
# Epoch: 1/250, Step: 5/64, Avg. test loss: 2980.940, time: 9.70, Avg. per iter 4.18, Est. time left 246.45
# Epoch: 1/250, Step: 10/64, Avg. test loss: 3011.248, time: 18.76, Avg. per iter 4.02, Est. time left 217.08
# Epoch: 1/250, Step: 15/64, Avg. test loss: 3086.164, time: 28.05, Avg. per iter 3.89, Est. time left 190.38
# Epoch: 1/250, Step: 20/64, Avg. test loss: 3073.478, time: 36.66, Avg. per iter 3.76, Est. time left 165.38
# Epoch: 1/250, Step: 25/64, Avg. test loss: 3046.460, time: 45.22, Avg. per iter 3.65, Est. time left 142.16
# Epoch: 1/250, Step: 30/64, Avg. test loss: 2964.418, time: 53.55, Avg. per iter 3.54, Est. time left 120.39
# Epoch: 1/250, Step: 35/64, Avg. test loss: 2952.627, time: 61.91, Avg. per iter 3.44, Est. time left 99.71
# Epoch: 1/250, Step: 40/64, Avg. test loss: 2985.940, time: 70.86, Avg. per iter 3.30, Est. time left 79.20
# Epoch: 1/250, Step: 45/64, Avg. test loss: 2972.262, time: 79.65, Avg. per iter 3.16, Est. time left 60.12
# Epoch: 1/250, Step: 50/64, Avg. test loss: 2956.572, time: 88.17, Avg. per iter 3.01, Est. time left 42.21
# Epoch: 1/250, Step: 55/64, Avg. test loss: 2980.260, time: 96.28, Avg. per iter 2.87, Est. time left 25.81
# Epoch: 1/250, Step: 60/64, Avg. test loss: 2992.900, time: 104.33, Avg. per iter 2.72, Est. time left 10.90
# Epoch: 1, Training loss: 4375.721, Test loss: 2991.504
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data64.tfrecords']
# Iterating length... 	Done: 75
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data195.tfrecords']
# Iterating length... 	Done: 66
# Training...
# gotcha
# Epoch: 2/250, Step: 5/75, Avg. train loss: 2856.760, time: 23.45, Avg. per iter 2.63, Est. time left 184.05
# Epoch: 2/250, Step: 10/75, Avg. train loss: 2768.309, time: 46.37, Avg. per iter 2.64, Est. time left 171.88
# Epoch: 2/250, Step: 15/75, Avg. train loss: 2679.146, time: 68.15, Avg. per iter 2.65, Est. time left 159.20
# Epoch: 2/250, Step: 20/75, Avg. train loss: 2654.185, time: 90.84, Avg. per iter 2.66, Est. time left 146.18
# Epoch: 2/250, Step: 25/75, Avg. train loss: 2616.889, time: 113.01, Avg. per iter 2.66, Est. time left 132.88
# Epoch: 2/250, Step: 30/75, Avg. train loss: 2601.148, time: 134.58, Avg. per iter 2.65, Est. time left 119.10
# Epoch: 2/250, Step: 35/75, Avg. train loss: 2628.829, time: 156.13, Avg. per iter 2.65, Est. time left 105.93
# Epoch: 2/250, Step: 40/75, Avg. train loss: 2679.433, time: 178.21, Avg. per iter 2.78, Est. time left 97.41
# Epoch: 2/250, Step: 45/75, Avg. train loss: 2691.738, time: 199.11, Avg. per iter 2.90, Est. time left 87.03
# Epoch: 2/250, Step: 50/75, Avg. train loss: 2672.948, time: 220.47, Avg. per iter 3.02, Est. time left 75.54
# Epoch: 2/250, Step: 55/75, Avg. train loss: 2662.840, time: 240.62, Avg. per iter 3.14, Est. time left 62.72
# Epoch: 2/250, Step: 60/75, Avg. train loss: 2649.655, time: 261.84, Avg. per iter 3.26, Est. time left 48.93
# Epoch: 2/250, Step: 65/75, Avg. train loss: 2636.176, time: 284.22, Avg. per iter 3.40, Est. time left 34.03
# Epoch: 2/250, Step: 70/75, Avg. train loss: 2638.005, time: 306.95, Avg. per iter 3.55, Est. time left 17.73
# Epoch: 2/250, Step: 75/75, Avg. train loss: 2594.347, time: 324.52, Avg. per iter 3.63, Est. time left 0.00
# Testing...
# gotcha
# Epoch: 2/250, Step: 5/66, Avg. test loss: 2440.442, time: 8.93, Avg. per iter 3.63, Est. time left 221.58
# Epoch: 2/250, Step: 10/66, Avg. test loss: 2377.276, time: 16.94, Avg. per iter 3.63, Est. time left 203.01
# Epoch: 2/250, Step: 15/66, Avg. test loss: 2330.853, time: 25.22, Avg. per iter 3.63, Est. time left 185.00
# Epoch: 2/250, Step: 20/66, Avg. test loss: 2289.595, time: 33.88, Avg. per iter 3.63, Est. time left 167.10
# Epoch: 2/250, Step: 25/66, Avg. test loss: 2263.569, time: 42.37, Avg. per iter 3.64, Est. time left 149.36
# Epoch: 2/250, Step: 30/66, Avg. test loss: 2228.063, time: 50.38, Avg. per iter 3.49, Est. time left 125.74
# Epoch: 2/250, Step: 35/66, Avg. test loss: 2223.354, time: 58.81, Avg. per iter 3.35, Est. time left 103.78
# Epoch: 2/250, Step: 40/66, Avg. test loss: 2183.608, time: 67.20, Avg. per iter 3.21, Est. time left 83.56
# Epoch: 2/250, Step: 45/66, Avg. test loss: 2186.542, time: 74.98, Avg. per iter 3.06, Est. time left 64.36
# Epoch: 2/250, Step: 50/66, Avg. test loss: 2175.403, time: 82.53, Avg. per iter 2.92, Est. time left 46.69
# Epoch: 2/250, Step: 55/66, Avg. test loss: 2182.097, time: 90.26, Avg. per iter 2.78, Est. time left 30.57
# Epoch: 2/250, Step: 60/66, Avg. test loss: 2182.559, time: 99.19, Avg. per iter 2.65, Est. time left 15.92
# Epoch: 2/250, Step: 65/66, Avg. test loss: 2157.415, time: 108.19, Avg. per iter 2.52, Est. time left 2.52
# Epoch: 2, Training loss: 2594.347, Test loss: 2137.984
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data143.tfrecords']
# Iterating length... 	Done: 66
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data188.tfrecords']
# Iterating length... 	Done: 64
# Training...
# gotcha
# Epoch: 3/250, Step: 5/66, Avg. train loss: 2559.336, time: 23.25, Avg. per iter 2.51, Est. time left 152.83
# Epoch: 3/250, Step: 10/66, Avg. train loss: 2553.249, time: 44.72, Avg. per iter 2.51, Est. time left 140.64
# Epoch: 3/250, Step: 15/66, Avg. train loss: 2517.105, time: 67.30, Avg. per iter 2.54, Est. time left 129.33
# Epoch: 3/250, Step: 20/66, Avg. train loss: 2462.531, time: 89.62, Avg. per iter 2.54, Est. time left 116.93
# Epoch: 3/250, Step: 25/66, Avg. train loss: 2439.288, time: 111.48, Avg. per iter 2.54, Est. time left 104.08
# Epoch: 3/250, Step: 30/66, Avg. train loss: 2408.321, time: 134.00, Avg. per iter 2.54, Est. time left 91.36
# Epoch: 3/250, Step: 35/66, Avg. train loss: 2411.141, time: 156.19, Avg. per iter 2.61, Est. time left 80.84
# Epoch: 3/250, Step: 40/66, Avg. train loss: 2389.339, time: 179.31, Avg. per iter 2.76, Est. time left 71.63
# Epoch: 3/250, Step: 45/66, Avg. train loss: 2385.084, time: 201.73, Avg. per iter 2.90, Est. time left 60.87
# Epoch: 3/250, Step: 50/66, Avg. train loss: 2393.553, time: 224.59, Avg. per iter 3.04, Est. time left 48.70
# Epoch: 3/250, Step: 55/66, Avg. train loss: 2376.923, time: 246.96, Avg. per iter 3.18, Est. time left 35.00
# Epoch: 3/250, Step: 60/66, Avg. train loss: 2349.604, time: 269.23, Avg. per iter 3.32, Est. time left 19.92
# Epoch: 3/250, Step: 65/66, Avg. train loss: 2328.490, time: 290.48, Avg. per iter 3.45, Est. time left 3.45
# Testing...
# gotcha
# Epoch: 3/250, Step: 5/64, Avg. test loss: 1931.704, time: 9.91, Avg. per iter 3.45, Est. time left 203.61
# Epoch: 3/250, Step: 10/64, Avg. test loss: 2017.611, time: 19.04, Avg. per iter 3.46, Est. time left 186.78
# Epoch: 3/250, Step: 15/64, Avg. test loss: 2088.867, time: 28.20, Avg. per iter 3.47, Est. time left 170.26
# Epoch: 3/250, Step: 20/64, Avg. test loss: 2113.559, time: 36.45, Avg. per iter 3.48, Est. time left 153.21
# Epoch: 3/250, Step: 25/64, Avg. test loss: 2114.591, time: 44.91, Avg. per iter 3.49, Est. time left 135.98
# Epoch: 3/250, Step: 30/64, Avg. test loss: 2141.664, time: 53.13, Avg. per iter 3.48, Est. time left 118.21
# Epoch: 3/250, Step: 35/64, Avg. test loss: 2132.550, time: 61.17, Avg. per iter 3.45, Est. time left 100.01
# Epoch: 3/250, Step: 40/64, Avg. test loss: 2174.615, time: 69.31, Avg. per iter 3.30, Est. time left 79.22
# Epoch: 3/250, Step: 45/64, Avg. test loss: 2152.698, time: 77.32, Avg. per iter 3.17, Est. time left 60.16
# Epoch: 3/250, Step: 50/64, Avg. test loss: 2153.746, time: 85.31, Avg. per iter 3.02, Est. time left 42.28
# Epoch: 3/250, Step: 55/64, Avg. test loss: 2135.564, time: 93.29, Avg. per iter 2.88, Est. time left 25.91
# Epoch: 3/250, Step: 60/64, Avg. test loss: 2146.853, time: 101.39, Avg. per iter 2.74, Est. time left 10.97
# Epoch: 3, Training loss: 2296.510, Test loss: 2140.039
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data139.tfrecords']
# Iterating length... 	Done: 65
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data190.tfrecords']
# Iterating length... 	Done: 65
# Training...
# gotcha
# Epoch: 4/250, Step: 5/65, Avg. train loss: 2156.817, time: 22.02, Avg. per iter 2.62, Est. time left 157.15
# Epoch: 4/250, Step: 10/65, Avg. train loss: 2204.906, time: 43.31, Avg. per iter 2.60, Est. time left 143.05
# Epoch: 4/250, Step: 15/65, Avg. train loss: 2221.616, time: 64.42, Avg. per iter 2.59, Est. time left 129.39
# Epoch: 4/250, Step: 20/65, Avg. train loss: 2250.421, time: 85.59, Avg. per iter 2.57, Est. time left 115.68
# Epoch: 4/250, Step: 25/65, Avg. train loss: 2251.578, time: 106.67, Avg. per iter 2.56, Est. time left 102.32
# Epoch: 4/250, Step: 30/65, Avg. train loss: 2209.146, time: 127.72, Avg. per iter 2.55, Est. time left 89.11
# Epoch: 4/250, Step: 35/65, Avg. train loss: 2194.059, time: 148.58, Avg. per iter 2.54, Est. time left 76.28
# Epoch: 4/250, Step: 40/65, Avg. train loss: 2182.947, time: 169.35, Avg. per iter 2.67, Est. time left 66.73
# Epoch: 4/250, Step: 45/65, Avg. train loss: 2154.861, time: 190.29, Avg. per iter 2.79, Est. time left 55.72
# Epoch: 4/250, Step: 50/65, Avg. train loss: 2152.908, time: 210.80, Avg. per iter 2.90, Est. time left 43.48
# Epoch: 4/250, Step: 55/65, Avg. train loss: 2127.655, time: 231.45, Avg. per iter 3.02, Est. time left 30.23
# Epoch: 4/250, Step: 60/65, Avg. train loss: 2106.340, time: 252.13, Avg. per iter 3.14, Est. time left 15.72
# Epoch: 4/250, Step: 65/65, Avg. train loss: 2096.485, time: 271.65, Avg. per iter 3.26, Est. time left 0.00
# Testing...
# gotcha
# Epoch: 4/250, Step: 5/65, Avg. test loss: 2782.778, time: 8.60, Avg. per iter 3.26, Est. time left 195.68
# Epoch: 4/250, Step: 10/65, Avg. test loss: 2569.132, time: 16.91, Avg. per iter 3.26, Est. time left 179.43
# Epoch: 4/250, Step: 15/65, Avg. test loss: 2521.286, time: 25.52, Avg. per iter 3.27, Est. time left 163.41
# Epoch: 4/250, Step: 20/65, Avg. test loss: 2538.247, time: 34.42, Avg. per iter 3.28, Est. time left 147.50
# Epoch: 4/250, Step: 25/65, Avg. test loss: 2526.613, time: 42.64, Avg. per iter 3.28, Est. time left 131.21
# Epoch: 4/250, Step: 30/65, Avg. test loss: 2487.942, time: 50.68, Avg. per iter 3.28, Est. time left 114.78
# Epoch: 4/250, Step: 35/65, Avg. test loss: 2494.292, time: 58.98, Avg. per iter 3.28, Est. time left 98.50
# Epoch: 4/250, Step: 40/65, Avg. test loss: 2523.388, time: 67.35, Avg. per iter 3.15, Est. time left 78.74
# Epoch: 4/250, Step: 45/65, Avg. test loss: 2507.501, time: 75.41, Avg. per iter 3.02, Est. time left 60.34
# Epoch: 4/250, Step: 50/65, Avg. test loss: 2514.333, time: 83.30, Avg. per iter 2.88, Est. time left 43.27
# Epoch: 4/250, Step: 55/65, Avg. test loss: 2510.413, time: 91.43, Avg. per iter 2.75, Est. time left 27.55
# Epoch: 4/250, Step: 60/65, Avg. test loss: 2510.240, time: 99.35, Avg. per iter 2.62, Est. time left 13.11
# Epoch: 4/250, Step: 65/65, Avg. test loss: 2491.962, time: 106.12, Avg. per iter 2.48, Est. time left 0.00
# Epoch: 4, Training loss: 2096.485, Test loss: 2491.962
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data143.tfrecords']
# Iterating length... 	Done: 66
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data189.tfrecords']
# Iterating length... 	Done: 56
# Training...
# gotcha
# Epoch: 5/250, Step: 5/66, Avg. train loss: 2140.061, time: 20.99, Avg. per iter 2.48, Est. time left 151.19
# Epoch: 5/250, Step: 10/66, Avg. train loss: 2007.016, time: 41.93, Avg. per iter 2.48, Est. time left 138.89
# Epoch: 5/250, Step: 15/66, Avg. train loss: 1958.411, time: 62.69, Avg. per iter 2.48, Est. time left 126.41
# Epoch: 5/250, Step: 20/66, Avg. train loss: 1985.069, time: 83.46, Avg. per iter 2.48, Est. time left 114.13
# Epoch: 5/250, Step: 25/66, Avg. train loss: 1985.189, time: 104.34, Avg. per iter 2.48, Est. time left 101.82
# Epoch: 5/250, Step: 30/66, Avg. train loss: 1937.305, time: 125.22, Avg. per iter 2.49, Est. time left 89.47
# Epoch: 5/250, Step: 35/66, Avg. train loss: 1905.646, time: 147.47, Avg. per iter 2.51, Est. time left 77.89
# Epoch: 5/250, Step: 40/66, Avg. train loss: 1865.396, time: 169.32, Avg. per iter 2.65, Est. time left 68.84
# Epoch: 5/250, Step: 45/66, Avg. train loss: 1828.217, time: 191.51, Avg. per iter 2.79, Est. time left 58.51
# Epoch: 5/250, Step: 50/66, Avg. train loss: 1813.195, time: 214.34, Avg. per iter 2.93, Est. time left 46.85
# Epoch: 5/250, Step: 55/66, Avg. train loss: 1794.933, time: 236.29, Avg. per iter 3.06, Est. time left 33.64
# Epoch: 5/250, Step: 60/66, Avg. train loss: 1777.289, time: 258.18, Avg. per iter 3.20, Est. time left 19.17
# Epoch: 5/250, Step: 65/66, Avg. train loss: 1775.681, time: 279.44, Avg. per iter 3.33, Est. time left 3.33
# Testing...
# gotcha
# Epoch: 5/250, Step: 5/56, Avg. test loss: 2377.815, time: 8.64, Avg. per iter 3.32, Est. time left 169.07
# Epoch: 5/250, Step: 10/56, Avg. test loss: 2371.198, time: 16.89, Avg. per iter 3.31, Est. time left 152.44
# Epoch: 5/250, Step: 15/56, Avg. test loss: 2350.580, time: 24.96, Avg. per iter 3.31, Est. time left 135.89
# Epoch: 5/250, Step: 20/56, Avg. test loss: 2352.057, time: 33.07, Avg. per iter 3.32, Est. time left 119.38
# Epoch: 5/250, Step: 25/56, Avg. test loss: 2365.929, time: 41.14, Avg. per iter 3.32, Est. time left 102.83
# Epoch: 5/250, Step: 30/56, Avg. test loss: 2369.396, time: 49.40, Avg. per iter 3.32, Est. time left 86.35
# Epoch: 5/250, Step: 35/56, Avg. test loss: 2367.211, time: 57.36, Avg. per iter 3.30, Est. time left 69.40
# Epoch: 5/250, Step: 40/56, Avg. test loss: 2369.915, time: 65.27, Avg. per iter 3.18, Est. time left 50.82
# Epoch: 5/250, Step: 45/56, Avg. test loss: 2354.891, time: 73.34, Avg. per iter 3.05, Est. time left 33.54
# Epoch: 5/250, Step: 50/56, Avg. test loss: 2343.046, time: 81.28, Avg. per iter 2.92, Est. time left 17.52
# Epoch: 5/250, Step: 55/56, Avg. test loss: 2349.190, time: 89.06, Avg. per iter 2.79, Est. time left 2.79
# Epoch: 5, Training loss: 1751.845, Test loss: 2332.605
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data4.tfrecords']
# Iterating length... 	Done: 69
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data197.tfrecords']
# Iterating length... 	Done: 71
# Training...
# gotcha
# Epoch: 6/250, Step: 5/69, Avg. train loss: 1549.864, time: 21.77, Avg. per iter 2.77, Est. time left 176.98
# Epoch: 6/250, Step: 10/69, Avg. train loss: 1535.698, time: 43.09, Avg. per iter 2.76, Est. time left 163.02
# Epoch: 6/250, Step: 15/69, Avg. train loss: 1422.364, time: 64.05, Avg. per iter 2.76, Est. time left 148.80
# Epoch: 6/250, Step: 20/69, Avg. train loss: 1375.556, time: 85.18, Avg. per iter 2.75, Est. time left 134.60
# Epoch: 6/250, Step: 25/69, Avg. train loss: 1392.737, time: 106.34, Avg. per iter 2.73, Est. time left 120.33
# Epoch: 6/250, Step: 30/69, Avg. train loss: 1393.070, time: 127.21, Avg. per iter 2.72, Est. time left 105.95
# Epoch: 6/250, Step: 35/69, Avg. train loss: 1415.015, time: 148.05, Avg. per iter 2.71, Est. time left 92.19
# Epoch: 6/250, Step: 40/69, Avg. train loss: 1399.660, time: 168.37, Avg. per iter 2.69, Est. time left 78.14
# Epoch: 6/250, Step: 45/69, Avg. train loss: 1428.802, time: 188.83, Avg. per iter 2.75, Est. time left 65.98
# Epoch: 6/250, Step: 50/69, Avg. train loss: 1476.773, time: 209.92, Avg. per iter 2.88, Est. time left 54.67
# Epoch: 6/250, Step: 55/69, Avg. train loss: 1489.129, time: 230.60, Avg. per iter 3.00, Est. time left 42.03
# Epoch: 6/250, Step: 60/69, Avg. train loss: 1493.908, time: 250.70, Avg. per iter 3.12, Est. time left 28.10
# Epoch: 6/250, Step: 65/69, Avg. train loss: 1497.233, time: 270.90, Avg. per iter 3.24, Est. time left 12.97
# Testing...
# gotcha
# Epoch: 6/250, Step: 5/71, Avg. test loss: 1528.110, time: 8.58, Avg. per iter 3.31, Est. time left 218.60
# Epoch: 6/250, Step: 10/71, Avg. test loss: 1534.227, time: 16.39, Avg. per iter 3.31, Est. time left 201.94
# Epoch: 6/250, Step: 15/71, Avg. test loss: 1528.996, time: 24.21, Avg. per iter 3.31, Est. time left 185.34
# Epoch: 6/250, Step: 20/71, Avg. test loss: 1550.368, time: 31.96, Avg. per iter 3.31, Est. time left 168.64
# Epoch: 6/250, Step: 25/71, Avg. test loss: 1567.954, time: 39.77, Avg. per iter 3.31, Est. time left 152.04
# Epoch: 6/250, Step: 30/71, Avg. test loss: 1545.163, time: 47.57, Avg. per iter 3.31, Est. time left 135.52
# Epoch: 6/250, Step: 35/71, Avg. test loss: 1551.995, time: 55.39, Avg. per iter 3.20, Est. time left 115.25
# Epoch: 6/250, Step: 40/71, Avg. test loss: 1547.081, time: 63.08, Avg. per iter 3.07, Est. time left 95.06
# Epoch: 6/250, Step: 45/71, Avg. test loss: 1550.414, time: 70.73, Avg. per iter 2.93, Est. time left 76.21
# Epoch: 6/250, Step: 50/71, Avg. test loss: 1551.345, time: 78.66, Avg. per iter 2.80, Est. time left 58.77
# Epoch: 6/250, Step: 55/71, Avg. test loss: 1545.981, time: 86.36, Avg. per iter 2.67, Est. time left 42.65
# Epoch: 6/250, Step: 60/71, Avg. test loss: 1556.847, time: 94.25, Avg. per iter 2.53, Est. time left 27.88
# Epoch: 6/250, Step: 65/71, Avg. test loss: 1558.611, time: 102.97, Avg. per iter 2.41, Est. time left 14.48
# Epoch: 6/250, Step: 70/71, Avg. test loss: 1567.594, time: 112.63, Avg. per iter 2.31, Est. time left 2.31
# Epoch: 6, Training loss: 1474.643, Test loss: 1556.793
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data56.tfrecords']
# Iterating length... 	Done: 65
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data187.tfrecords']
# Iterating length... 	Done: 58
# Training...
# gotcha
# Epoch: 7/250, Step: 5/65, Avg. train loss: 1597.023, time: 26.09, Avg. per iter 2.32, Est. time left 139.39
# Epoch: 7/250, Step: 10/65, Avg. train loss: 1579.052, time: 47.35, Avg. per iter 2.32, Est. time left 127.86
# Epoch: 7/250, Step: 15/65, Avg. train loss: 1559.958, time: 71.90, Avg. per iter 2.36, Est. time left 118.17
# Epoch: 7/250, Step: 20/65, Avg. train loss: 1530.785, time: 95.86, Avg. per iter 2.40, Est. time left 108.07
# Epoch: 7/250, Step: 25/65, Avg. train loss: 1529.889, time: 119.89, Avg. per iter 2.44, Est. time left 97.59
# Epoch: 7/250, Step: 30/65, Avg. train loss: 1531.020, time: 143.94, Avg. per iter 2.53, Est. time left 88.51
# Epoch: 7/250, Step: 35/65, Avg. train loss: 1494.886, time: 167.11, Avg. per iter 2.68, Est. time left 80.38
# Epoch: 7/250, Step: 40/65, Avg. train loss: 1508.007, time: 193.95, Avg. per iter 2.87, Est. time left 71.76
# Epoch: 7/250, Step: 45/65, Avg. train loss: 1487.287, time: 220.40, Avg. per iter 3.06, Est. time left 61.13
# Epoch: 7/250, Step: 50/65, Avg. train loss: 1462.900, time: 244.39, Avg. per iter 3.22, Est. time left 48.28
# Epoch: 7/250, Step: 55/65, Avg. train loss: 1456.552, time: 268.38, Avg. per iter 3.38, Est. time left 33.80
# Epoch: 7/250, Step: 60/65, Avg. train loss: 1456.269, time: 291.59, Avg. per iter 3.53, Est. time left 17.67
# Epoch: 7/250, Step: 65/65, Avg. train loss: 1437.994, time: 311.47, Avg. per iter 3.65, Est. time left 0.00
# Testing...
# gotcha
# Epoch: 7/250, Step: 5/58, Avg. test loss: 2380.771, time: 9.41, Avg. per iter 3.67, Est. time left 194.42
# Epoch: 7/250, Step: 10/58, Avg. test loss: 2425.653, time: 18.41, Avg. per iter 3.68, Est. time left 176.65
# Epoch: 7/250, Step: 15/58, Avg. test loss: 2445.038, time: 26.72, Avg. per iter 3.69, Est. time left 158.46
# Epoch: 7/250, Step: 20/58, Avg. test loss: 2464.154, time: 35.54, Avg. per iter 3.70, Est. time left 140.45
# Epoch: 7/250, Step: 25/58, Avg. test loss: 2469.245, time: 44.07, Avg. per iter 3.70, Est. time left 122.19
# Epoch: 7/250, Step: 30/58, Avg. test loss: 2471.957, time: 52.55, Avg. per iter 3.70, Est. time left 103.50
# Epoch: 7/250, Step: 35/58, Avg. test loss: 2484.571, time: 61.56, Avg. per iter 3.70, Est. time left 85.18
# Epoch: 7/250, Step: 40/58, Avg. test loss: 2487.396, time: 70.41, Avg. per iter 3.54, Est. time left 63.64
# Epoch: 7/250, Step: 45/58, Avg. test loss: 2503.237, time: 79.07, Avg. per iter 3.41, Est. time left 44.32
# Epoch: 7/250, Step: 50/58, Avg. test loss: 2511.802, time: 88.26, Avg. per iter 3.26, Est. time left 26.05
# Epoch: 7/250, Step: 55/58, Avg. test loss: 2508.923, time: 97.68, Avg. per iter 3.11, Est. time left 9.33
# Epoch: 7, Training loss: 1437.994, Test loss: 2506.111
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data108.tfrecords']
# Iterating length... 	Done: 62
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data193.tfrecords']
# Iterating length... 	Done: 58
# Training...
# gotcha
# Epoch: 8/250, Step: 5/62, Avg. train loss: 1762.981, time: 24.74, Avg. per iter 3.03, Est. time left 172.64
# Epoch: 8/250, Step: 10/62, Avg. train loss: 1556.771, time: 49.11, Avg. per iter 3.04, Est. time left 157.94
# Epoch: 8/250, Step: 15/62, Avg. train loss: 1514.277, time: 74.71, Avg. per iter 3.05, Est. time left 143.55
# Epoch: 8/250, Step: 20/62, Avg. train loss: 1486.512, time: 99.69, Avg. per iter 3.01, Est. time left 126.62
# Epoch: 8/250, Step: 25/62, Avg. train loss: 1453.585, time: 124.24, Avg. per iter 3.01, Est. time left 111.53
# Epoch: 8/250, Step: 30/62, Avg. train loss: 1451.129, time: 145.60, Avg. per iter 2.99, Est. time left 95.76
# Epoch: 8/250, Step: 35/62, Avg. train loss: 1473.844, time: 166.76, Avg. per iter 2.96, Est. time left 80.04
# Epoch: 8/250, Step: 40/62, Avg. train loss: 1459.069, time: 187.79, Avg. per iter 2.95, Est. time left 64.99
# Epoch: 8/250, Step: 45/62, Avg. train loss: 1462.317, time: 208.95, Avg. per iter 3.04, Est. time left 51.68
# Epoch: 8/250, Step: 50/62, Avg. train loss: 1460.139, time: 230.19, Avg. per iter 3.17, Est. time left 38.00
# Epoch: 8/250, Step: 55/62, Avg. train loss: 1444.175, time: 252.78, Avg. per iter 3.30, Est. time left 23.13
# Epoch: 8/250, Step: 60/62, Avg. train loss: 1436.199, time: 274.10, Avg. per iter 3.43, Est. time left 6.86
# Testing...
# gotcha
# Epoch: 8/250, Step: 5/58, Avg. test loss: 1567.427, time: 10.56, Avg. per iter 3.47, Est. time left 183.98
# Epoch: 8/250, Step: 10/58, Avg. test loss: 1604.474, time: 20.46, Avg. per iter 3.49, Est. time left 167.30
# Epoch: 8/250, Step: 15/58, Avg. test loss: 1538.788, time: 29.91, Avg. per iter 3.49, Est. time left 150.04
# Epoch: 8/250, Step: 20/58, Avg. test loss: 1520.789, time: 39.22, Avg. per iter 3.49, Est. time left 132.77
# Epoch: 8/250, Step: 25/58, Avg. test loss: 1534.842, time: 49.29, Avg. per iter 3.51, Est. time left 115.77
# Epoch: 8/250, Step: 30/58, Avg. test loss: 1516.327, time: 59.88, Avg. per iter 3.52, Est. time left 98.62
# Epoch: 8/250, Step: 35/58, Avg. test loss: 1509.607, time: 69.25, Avg. per iter 3.52, Est. time left 81.00
# Epoch: 8/250, Step: 40/58, Avg. test loss: 1519.416, time: 78.99, Avg. per iter 3.46, Est. time left 62.34
# Epoch: 8/250, Step: 45/58, Avg. test loss: 1532.428, time: 88.29, Avg. per iter 3.32, Est. time left 43.13
# Epoch: 8/250, Step: 50/58, Avg. test loss: 1535.083, time: 98.10, Avg. per iter 3.17, Est. time left 25.35
# Epoch: 8/250, Step: 55/58, Avg. test loss: 1540.285, time: 107.55, Avg. per iter 3.01, Est. time left 9.02
# Epoch: 8, Training loss: 1421.688, Test loss: 1532.138
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data8.tfrecords']
# Iterating length... 	Done: 64
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data192.tfrecords']
# Iterating length... 	Done: 80
# Training...
# gotcha
# Epoch: 9/250, Step: 5/64, Avg. train loss: 1374.228, time: 24.89, Avg. per iter 2.90, Est. time left 171.27
# Epoch: 9/250, Step: 10/64, Avg. train loss: 1486.804, time: 50.49, Avg. per iter 2.95, Est. time left 159.04
# Epoch: 9/250, Step: 15/64, Avg. train loss: 1435.201, time: 76.02, Avg. per iter 2.99, Est. time left 146.45
# Epoch: 9/250, Step: 20/64, Avg. train loss: 1413.758, time: 98.45, Avg. per iter 3.00, Est. time left 132.12
# Epoch: 9/250, Step: 25/64, Avg. train loss: 1456.630, time: 120.99, Avg. per iter 3.02, Est. time left 117.65
# Epoch: 9/250, Step: 30/64, Avg. train loss: 1484.808, time: 143.99, Avg. per iter 3.03, Est. time left 103.16
# Epoch: 9/250, Step: 35/64, Avg. train loss: 1501.271, time: 167.87, Avg. per iter 3.05, Est. time left 88.37
# Epoch: 9/250, Step: 40/64, Avg. train loss: 1471.082, time: 193.36, Avg. per iter 3.09, Est. time left 74.14
# Epoch: 9/250, Step: 45/64, Avg. train loss: 1472.670, time: 220.07, Avg. per iter 3.24, Est. time left 61.51
# Epoch: 9/250, Step: 50/64, Avg. train loss: 1454.532, time: 244.54, Avg. per iter 3.38, Est. time left 47.33
# Epoch: 9/250, Step: 55/64, Avg. train loss: 1439.639, time: 270.23, Avg. per iter 3.54, Est. time left 31.88
# Epoch: 9/250, Step: 60/64, Avg. train loss: 1418.549, time: 294.72, Avg. per iter 3.69, Est. time left 14.77
# Testing...
# gotcha
# Epoch: 9/250, Step: 5/80, Avg. test loss: 2016.514, time: 8.76, Avg. per iter 3.76, Est. time left 282.29
# Epoch: 9/250, Step: 10/80, Avg. test loss: 1927.738, time: 17.15, Avg. per iter 3.75, Est. time left 262.50
# Epoch: 9/250, Step: 15/80, Avg. test loss: 1892.446, time: 25.02, Avg. per iter 3.73, Est. time left 242.55
# Epoch: 9/250, Step: 20/80, Avg. test loss: 1901.715, time: 32.64, Avg. per iter 3.71, Est. time left 222.84
# Epoch: 9/250, Step: 25/80, Avg. test loss: 1879.073, time: 40.36, Avg. per iter 3.69, Est. time left 203.14
# Epoch: 9/250, Step: 30/80, Avg. test loss: 1887.259, time: 48.11, Avg. per iter 3.67, Est. time left 183.73
# Epoch: 9/250, Step: 35/80, Avg. test loss: 1898.803, time: 56.79, Avg. per iter 3.67, Est. time left 165.07
# Epoch: 9/250, Step: 40/80, Avg. test loss: 1893.428, time: 64.82, Avg. per iter 3.54, Est. time left 141.57
# Epoch: 9/250, Step: 45/80, Avg. test loss: 1887.260, time: 72.65, Avg. per iter 3.37, Est. time left 117.79
# Epoch: 9/250, Step: 50/80, Avg. test loss: 1876.155, time: 80.28, Avg. per iter 3.19, Est. time left 95.58
# Epoch: 9/250, Step: 55/80, Avg. test loss: 1875.667, time: 87.97, Avg. per iter 3.03, Est. time left 75.86
# Epoch: 9/250, Step: 60/80, Avg. test loss: 1877.740, time: 96.05, Avg. per iter 2.89, Est. time left 57.83
# Epoch: 9/250, Step: 65/80, Avg. test loss: 1876.908, time: 104.21, Avg. per iter 2.74, Est. time left 41.11
# Epoch: 9/250, Step: 70/80, Avg. test loss: 1866.496, time: 111.94, Avg. per iter 2.58, Est. time left 25.81
# Epoch: 9/250, Step: 75/80, Avg. test loss: 1869.349, time: 119.51, Avg. per iter 2.41, Est. time left 12.04
# Epoch: 9/250, Step: 80/80, Avg. test loss: 1858.998, time: 126.47, Avg. per iter 2.20, Est. time left 0.00
# Epoch: 9, Training loss: 1400.702, Test loss: 1858.998
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data125.tfrecords']
# Iterating length... 	Done: 67
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data189.tfrecords']
# Iterating length... 	Done: 56
# Training...
# gotcha
# Epoch: 10/250, Step: 5/67, Avg. train loss: 1346.706, time: 21.18, Avg. per iter 2.17, Est. time left 134.28
# Epoch: 10/250, Step: 10/67, Avg. train loss: 1396.883, time: 41.77, Avg. per iter 2.13, Est. time left 121.21
# Epoch: 10/250, Step: 15/67, Avg. train loss: 1437.998, time: 63.21, Avg. per iter 2.08, Est. time left 108.41
# Epoch: 10/250, Step: 20/67, Avg. train loss: 1504.252, time: 84.69, Avg. per iter 2.09, Est. time left 98.03
# Epoch: 10/250, Step: 25/67, Avg. train loss: 1500.218, time: 105.91, Avg. per iter 2.21, Est. time left 93.01
# Epoch: 10/250, Step: 30/67, Avg. train loss: 1509.814, time: 126.49, Avg. per iter 2.34, Est. time left 86.45
# Epoch: 10/250, Step: 35/67, Avg. train loss: 1522.046, time: 147.33, Avg. per iter 2.47, Est. time left 78.92
# Epoch: 10/250, Step: 40/67, Avg. train loss: 1522.399, time: 168.03, Avg. per iter 2.60, Est. time left 70.13
# Epoch: 10/250, Step: 45/67, Avg. train loss: 1547.003, time: 189.94, Avg. per iter 2.74, Est. time left 60.26
# Epoch: 10/250, Step: 50/67, Avg. train loss: 1542.030, time: 211.83, Avg. per iter 2.88, Est. time left 48.97
# Epoch: 10/250, Step: 55/67, Avg. train loss: 1536.511, time: 236.98, Avg. per iter 3.05, Est. time left 36.54
# Epoch: 10/250, Step: 60/67, Avg. train loss: 1514.995, time: 260.16, Avg. per iter 3.20, Est. time left 22.38
# Epoch: 10/250, Step: 65/67, Avg. train loss: 1500.291, time: 283.21, Avg. per iter 3.35, Est. time left 6.70
# Testing...
# gotcha
# Epoch: 10/250, Step: 5/56, Avg. test loss: 1232.666, time: 9.85, Avg. per iter 3.39, Est. time left 173.06
# Epoch: 10/250, Step: 10/56, Avg. test loss: 1316.399, time: 20.05, Avg. per iter 3.42, Est. time left 157.26
# Epoch: 10/250, Step: 15/56, Avg. test loss: 1283.753, time: 29.48, Avg. per iter 3.43, Est. time left 140.58
# Epoch: 10/250, Step: 20/56, Avg. test loss: 1352.648, time: 38.97, Avg. per iter 3.44, Est. time left 124.02
# Epoch: 10/250, Step: 25/56, Avg. test loss: 1352.739, time: 48.20, Avg. per iter 3.46, Est. time left 107.29
# Epoch: 10/250, Step: 30/56, Avg. test loss: 1375.081, time: 57.52, Avg. per iter 3.48, Est. time left 90.44
# Epoch: 10/250, Step: 35/56, Avg. test loss: 1370.267, time: 66.56, Avg. per iter 3.44, Est. time left 72.30
# Epoch: 10/250, Step: 40/56, Avg. test loss: 1365.029, time: 75.64, Avg. per iter 3.33, Est. time left 53.27
# Epoch: 10/250, Step: 45/56, Avg. test loss: 1378.274, time: 84.41, Avg. per iter 3.21, Est. time left 35.31
# Epoch: 10/250, Step: 50/56, Avg. test loss: 1367.782, time: 93.52, Avg. per iter 3.08, Est. time left 18.49
# Epoch: 10/250, Step: 55/56, Avg. test loss: 1356.358, time: 102.56, Avg. per iter 2.96, Est. time left 2.96
# Epoch: 10, Training loss: 1474.812, Test loss: 1348.447
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data3.tfrecords']
# Iterating length... 	Done: 75
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data180.tfrecords']
# Iterating length... 	Done: 64
# Training...
# gotcha
# Epoch: 11/250, Step: 5/75, Avg. train loss: 1353.484, time: 22.22, Avg. per iter 2.94, Est. time left 205.91
# Epoch: 11/250, Step: 10/75, Avg. train loss: 1342.738, time: 46.10, Avg. per iter 2.97, Est. time left 193.20
# Epoch: 11/250, Step: 15/75, Avg. train loss: 1359.800, time: 70.47, Avg. per iter 3.01, Est. time left 180.58
# Epoch: 11/250, Step: 20/75, Avg. train loss: 1382.558, time: 95.31, Avg. per iter 3.04, Est. time left 167.46
# Epoch: 11/250, Step: 25/75, Avg. train loss: 1376.887, time: 119.24, Avg. per iter 3.06, Est. time left 153.19
# Epoch: 11/250, Step: 30/75, Avg. train loss: 1389.252, time: 143.33, Avg. per iter 3.06, Est. time left 137.89
# Epoch: 11/250, Step: 35/75, Avg. train loss: 1378.652, time: 168.14, Avg. per iter 3.08, Est. time left 123.22
# Epoch: 11/250, Step: 40/75, Avg. train loss: 1373.968, time: 192.72, Avg. per iter 3.09, Est. time left 108.13
# Epoch: 11/250, Step: 45/75, Avg. train loss: 1370.028, time: 214.42, Avg. per iter 3.14, Est. time left 94.15
# Epoch: 11/250, Step: 50/75, Avg. train loss: 1360.849, time: 237.83, Avg. per iter 3.27, Est. time left 81.87
# Epoch: 11/250, Step: 55/75, Avg. train loss: 1356.781, time: 261.10, Avg. per iter 3.41, Est. time left 68.21
# Epoch: 11/250, Step: 60/75, Avg. train loss: 1352.147, time: 282.53, Avg. per iter 3.53, Est. time left 52.92
# Epoch: 11/250, Step: 65/75, Avg. train loss: 1343.307, time: 303.82, Avg. per iter 3.65, Est. time left 36.47
# Epoch: 11/250, Step: 70/75, Avg. train loss: 1341.882, time: 324.90, Avg. per iter 3.77, Est. time left 18.83
# Epoch: 11/250, Step: 75/75, Avg. train loss: 1328.448, time: 344.10, Avg. per iter 3.87, Est. time left 0.00
# Testing...
# gotcha
# Epoch: 11/250, Step: 5/64, Avg. test loss: 1459.438, time: 9.14, Avg. per iter 3.86, Est. time left 227.95
# Epoch: 11/250, Step: 10/64, Avg. test loss: 1422.736, time: 17.79, Avg. per iter 3.86, Est. time left 208.43
# Epoch: 11/250, Step: 15/64, Avg. test loss: 1376.921, time: 26.45, Avg. per iter 3.86, Est. time left 189.01
# Epoch: 11/250, Step: 20/64, Avg. test loss: 1368.346, time: 34.70, Avg. per iter 3.85, Est. time left 169.39
# Epoch: 11/250, Step: 25/64, Avg. test loss: 1364.828, time: 43.21, Avg. per iter 3.85, Est. time left 150.10
# Epoch: 11/250, Step: 30/64, Avg. test loss: 1344.357, time: 51.68, Avg. per iter 3.71, Est. time left 126.29
# Epoch: 11/250, Step: 35/64, Avg. test loss: 1319.099, time: 60.21, Avg. per iter 3.56, Est. time left 103.26
# Epoch: 11/250, Step: 40/64, Avg. test loss: 1323.732, time: 68.45, Avg. per iter 3.40, Est. time left 81.59
# Epoch: 11/250, Step: 45/64, Avg. test loss: 1326.429, time: 76.65, Avg. per iter 3.23, Est. time left 61.43
# Epoch: 11/250, Step: 50/64, Avg. test loss: 1324.686, time: 84.87, Avg. per iter 3.08, Est. time left 43.07
# Epoch: 11/250, Step: 55/64, Avg. test loss: 1319.377, time: 93.10, Avg. per iter 2.92, Est. time left 26.26
# Epoch: 11/250, Step: 60/64, Avg. test loss: 1319.759, time: 101.46, Avg. per iter 2.75, Est. time left 11.01
# Epoch: 11, Training loss: 1328.448, Test loss: 1310.938
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data122.tfrecords']
# Iterating length... 	Done: 59
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data187.tfrecords']
# Iterating length... 	Done: 58
# Training...
# gotcha
# Epoch: 12/250, Step: 5/59, Avg. train loss: 1179.820, time: 22.34, Avg. per iter 2.62, Est. time left 141.32
# Epoch: 12/250, Step: 10/59, Avg. train loss: 1237.414, time: 45.44, Avg. per iter 2.61, Est. time left 128.00
# Epoch: 12/250, Step: 15/59, Avg. train loss: 1257.490, time: 69.13, Avg. per iter 2.62, Est. time left 115.30
# Epoch: 12/250, Step: 20/59, Avg. train loss: 1268.294, time: 91.63, Avg. per iter 2.63, Est. time left 102.47
# Epoch: 12/250, Step: 25/59, Avg. train loss: 1271.353, time: 114.25, Avg. per iter 2.64, Est. time left 89.77
# Epoch: 12/250, Step: 30/59, Avg. train loss: 1267.942, time: 136.32, Avg. per iter 2.65, Est. time left 76.87
# Epoch: 12/250, Step: 35/59, Avg. train loss: 1261.311, time: 157.83, Avg. per iter 2.65, Est. time left 63.71
# Epoch: 12/250, Step: 40/59, Avg. train loss: 1274.433, time: 179.14, Avg. per iter 2.77, Est. time left 52.68
# Epoch: 12/250, Step: 45/59, Avg. train loss: 1282.936, time: 200.65, Avg. per iter 2.90, Est. time left 40.62
# Epoch: 12/250, Step: 50/59, Avg. train loss: 1274.923, time: 222.05, Avg. per iter 3.03, Est. time left 27.26
# Epoch: 12/250, Step: 55/59, Avg. train loss: 1270.498, time: 246.31, Avg. per iter 3.19, Est. time left 12.75
# Testing...
# gotcha
# Epoch: 12/250, Step: 5/58, Avg. test loss: 1345.390, time: 9.77, Avg. per iter 3.28, Est. time left 173.94
# Epoch: 12/250, Step: 10/58, Avg. test loss: 1381.891, time: 19.10, Avg. per iter 3.29, Est. time left 157.98
# Epoch: 12/250, Step: 15/58, Avg. test loss: 1357.119, time: 28.17, Avg. per iter 3.30, Est. time left 141.73
# Epoch: 12/250, Step: 20/58, Avg. test loss: 1362.084, time: 37.80, Avg. per iter 3.31, Est. time left 125.87
# Epoch: 12/250, Step: 25/58, Avg. test loss: 1364.021, time: 47.63, Avg. per iter 3.33, Est. time left 109.80
# Epoch: 12/250, Step: 30/58, Avg. test loss: 1369.076, time: 56.98, Avg. per iter 3.34, Est. time left 93.47
# Epoch: 12/250, Step: 35/58, Avg. test loss: 1372.087, time: 66.15, Avg. per iter 3.35, Est. time left 76.99
# Epoch: 12/250, Step: 40/58, Avg. test loss: 1368.495, time: 74.94, Avg. per iter 3.35, Est. time left 60.38
# Epoch: 12/250, Step: 45/58, Avg. test loss: 1380.790, time: 83.74, Avg. per iter 3.25, Est. time left 42.26
# Epoch: 12/250, Step: 50/58, Avg. test loss: 1380.648, time: 92.95, Avg. per iter 3.11, Est. time left 24.91
# Epoch: 12/250, Step: 55/58, Avg. test loss: 1390.070, time: 101.73, Avg. per iter 2.96, Est. time left 8.89
# Epoch: 12, Training loss: 1263.448, Test loss: 1382.444
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data89.tfrecords']
# Iterating length... 	Done: 66
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data186.tfrecords']
# Iterating length... 	Done: 78
# Training...
# gotcha
# Epoch: 13/250, Step: 5/66, Avg. train loss: 1439.894, time: 24.04, Avg. per iter 2.89, Est. time left 176.51
# Epoch: 13/250, Step: 10/66, Avg. train loss: 1417.643, time: 46.53, Avg. per iter 2.90, Est. time left 162.18
# Epoch: 13/250, Step: 15/66, Avg. train loss: 1419.583, time: 69.87, Avg. per iter 2.91, Est. time left 148.22
# Epoch: 13/250, Step: 20/66, Avg. train loss: 1398.949, time: 94.30, Avg. per iter 2.94, Est. time left 135.10
# Epoch: 13/250, Step: 25/66, Avg. train loss: 1384.557, time: 118.04, Avg. per iter 2.96, Est. time left 121.32
# Epoch: 13/250, Step: 30/66, Avg. train loss: 1384.774, time: 142.86, Avg. per iter 2.99, Est. time left 107.77
# Epoch: 13/250, Step: 35/66, Avg. train loss: 1374.169, time: 165.64, Avg. per iter 3.00, Est. time left 93.01
# Epoch: 13/250, Step: 40/66, Avg. train loss: 1366.856, time: 189.08, Avg. per iter 2.99, Est. time left 77.70
# Epoch: 13/250, Step: 45/66, Avg. train loss: 1365.888, time: 210.08, Avg. per iter 3.09, Est. time left 64.80
# Epoch: 13/250, Step: 50/66, Avg. train loss: 1351.923, time: 231.49, Avg. per iter 3.20, Est. time left 51.27
# Epoch: 13/250, Step: 55/66, Avg. train loss: 1346.209, time: 252.91, Avg. per iter 3.33, Est. time left 36.66
# Epoch: 13/250, Step: 60/66, Avg. train loss: 1346.006, time: 274.11, Avg. per iter 3.45, Est. time left 20.69
# Epoch: 13/250, Step: 65/66, Avg. train loss: 1342.518, time: 298.69, Avg. per iter 3.60, Est. time left 3.60
# Testing...
# gotcha
# Epoch: 13/250, Step: 5/78, Avg. test loss: 1087.430, time: 8.57, Avg. per iter 3.57, Est. time left 260.39
# Epoch: 13/250, Step: 10/78, Avg. test loss: 1069.422, time: 16.59, Avg. per iter 3.56, Est. time left 241.77
# Epoch: 13/250, Step: 15/78, Avg. test loss: 1115.690, time: 24.39, Avg. per iter 3.54, Est. time left 223.26
# Epoch: 13/250, Step: 20/78, Avg. test loss: 1123.381, time: 32.19, Avg. per iter 3.53, Est. time left 204.93
# Epoch: 13/250, Step: 25/78, Avg. test loss: 1125.247, time: 40.17, Avg. per iter 3.52, Est. time left 186.67
# Epoch: 13/250, Step: 30/78, Avg. test loss: 1125.389, time: 48.80, Avg. per iter 3.52, Est. time left 168.90
# Epoch: 13/250, Step: 35/78, Avg. test loss: 1133.277, time: 57.28, Avg. per iter 3.49, Est. time left 150.11
# Epoch: 13/250, Step: 40/78, Avg. test loss: 1153.846, time: 65.26, Avg. per iter 3.33, Est. time left 126.44
# Epoch: 13/250, Step: 45/78, Avg. test loss: 1152.413, time: 73.40, Avg. per iter 3.19, Est. time left 105.37
# Epoch: 13/250, Step: 50/78, Avg. test loss: 1150.446, time: 81.23, Avg. per iter 3.03, Est. time left 84.85
# Epoch: 13/250, Step: 55/78, Avg. test loss: 1148.652, time: 88.96, Avg. per iter 2.87, Est. time left 65.94
# Epoch: 13/250, Step: 60/78, Avg. test loss: 1152.619, time: 97.31, Avg. per iter 2.71, Est. time left 48.79
# Epoch: 13/250, Step: 65/78, Avg. test loss: 1153.353, time: 105.79, Avg. per iter 2.54, Est. time left 33.06
# Epoch: 13/250, Step: 70/78, Avg. test loss: 1158.620, time: 114.01, Avg. per iter 2.41, Est. time left 19.26
# Epoch: 13/250, Step: 75/78, Avg. test loss: 1159.057, time: 122.65, Avg. per iter 2.26, Est. time left 6.78
# Epoch: 13, Training loss: 1323.486, Test loss: 1153.539
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data91.tfrecords']
# Iterating length... 	Done: 63
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data188.tfrecords']
# Iterating length... 	Done: 64
# Training...
# gotcha
# Epoch: 14/250, Step: 5/63, Avg. train loss: 1233.849, time: 23.60, Avg. per iter 2.20, Est. time left 127.37
# Epoch: 14/250, Step: 10/63, Avg. train loss: 1291.075, time: 46.51, Avg. per iter 2.21, Est. time left 117.06
# Epoch: 14/250, Step: 15/63, Avg. train loss: 1263.993, time: 68.21, Avg. per iter 2.21, Est. time left 106.31
# Epoch: 14/250, Step: 20/63, Avg. train loss: 1276.216, time: 88.96, Avg. per iter 2.18, Est. time left 93.60
# Epoch: 14/250, Step: 25/63, Avg. train loss: 1262.870, time: 109.41, Avg. per iter 2.28, Est. time left 86.78
# Epoch: 14/250, Step: 30/63, Avg. train loss: 1286.522, time: 129.64, Avg. per iter 2.41, Est. time left 79.39
# Epoch: 14/250, Step: 35/63, Avg. train loss: 1263.666, time: 149.96, Avg. per iter 2.53, Est. time left 70.90
# Epoch: 14/250, Step: 40/63, Avg. train loss: 1255.757, time: 170.41, Avg. per iter 2.66, Est. time left 61.12
# Epoch: 14/250, Step: 45/63, Avg. train loss: 1261.243, time: 190.69, Avg. per iter 2.78, Est. time left 50.09
# Epoch: 14/250, Step: 50/63, Avg. train loss: 1261.706, time: 211.15, Avg. per iter 2.90, Est. time left 37.71
# Epoch: 14/250, Step: 55/63, Avg. train loss: 1255.492, time: 231.96, Avg. per iter 3.03, Est. time left 24.22
# Epoch: 14/250, Step: 60/63, Avg. train loss: 1243.489, time: 252.74, Avg. per iter 3.15, Est. time left 9.45
# Testing...
# gotcha
# Epoch: 14/250, Step: 5/64, Avg. test loss: 1137.942, time: 8.48, Avg. per iter 3.20, Est. time left 189.00
# Epoch: 14/250, Step: 10/64, Avg. test loss: 1180.823, time: 16.94, Avg. per iter 3.21, Est. time left 173.36
# Epoch: 14/250, Step: 15/64, Avg. test loss: 1164.066, time: 24.88, Avg. per iter 3.21, Est. time left 157.40
# Epoch: 14/250, Step: 20/64, Avg. test loss: 1151.494, time: 32.93, Avg. per iter 3.21, Est. time left 141.12
# Epoch: 14/250, Step: 25/64, Avg. test loss: 1177.491, time: 40.99, Avg. per iter 3.20, Est. time left 124.93
# Epoch: 14/250, Step: 30/64, Avg. test loss: 1183.924, time: 49.22, Avg. per iter 3.20, Est. time left 108.86
# Epoch: 14/250, Step: 35/64, Avg. test loss: 1178.369, time: 57.13, Avg. per iter 3.20, Est. time left 92.70
# Epoch: 14/250, Step: 40/64, Avg. test loss: 1171.685, time: 65.01, Avg. per iter 3.11, Est. time left 74.64
# Epoch: 14/250, Step: 45/64, Avg. test loss: 1177.567, time: 72.93, Avg. per iter 2.96, Est. time left 56.29
# Epoch: 14/250, Step: 50/64, Avg. test loss: 1175.464, time: 80.53, Avg. per iter 2.81, Est. time left 39.36
# Epoch: 14/250, Step: 55/64, Avg. test loss: 1181.336, time: 88.26, Avg. per iter 2.68, Est. time left 24.14
# Epoch: 14/250, Step: 60/64, Avg. test loss: 1177.535, time: 95.90, Avg. per iter 2.55, Est. time left 10.21
# Epoch: 14, Training loss: 1221.461, Test loss: 1172.140
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data97.tfrecords']
# Iterating length... 	Done: 67
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data197.tfrecords']
# Iterating length... 	Done: 71
# Training...
# gotcha
# Epoch: 15/250, Step: 5/67, Avg. train loss: 1142.544, time: 21.17, Avg. per iter 2.46, Est. time left 152.22
# Epoch: 15/250, Step: 10/67, Avg. train loss: 1089.459, time: 41.19, Avg. per iter 2.45, Est. time left 139.71
# Epoch: 15/250, Step: 15/67, Avg. train loss: 1040.212, time: 61.54, Avg. per iter 2.45, Est. time left 127.44
# Epoch: 15/250, Step: 20/67, Avg. train loss: 1045.127, time: 81.58, Avg. per iter 2.45, Est. time left 115.01
# Epoch: 15/250, Step: 25/67, Avg. train loss: 1050.026, time: 101.99, Avg. per iter 2.44, Est. time left 102.68
# Epoch: 15/250, Step: 30/67, Avg. train loss: 1062.245, time: 122.20, Avg. per iter 2.44, Est. time left 90.29
# Epoch: 15/250, Step: 35/67, Avg. train loss: 1101.040, time: 142.36, Avg. per iter 2.43, Est. time left 77.90
# Epoch: 15/250, Step: 40/67, Avg. train loss: 1102.562, time: 162.42, Avg. per iter 2.55, Est. time left 68.92
# Epoch: 15/250, Step: 45/67, Avg. train loss: 1089.466, time: 182.66, Avg. per iter 2.67, Est. time left 58.77
# Epoch: 15/250, Step: 50/67, Avg. train loss: 1085.982, time: 203.03, Avg. per iter 2.79, Est. time left 47.50
# Epoch: 15/250, Step: 55/67, Avg. train loss: 1085.478, time: 223.25, Avg. per iter 2.92, Est. time left 35.00
# Epoch: 15/250, Step: 60/67, Avg. train loss: 1088.996, time: 243.53, Avg. per iter 3.04, Est. time left 21.27
# Epoch: 15/250, Step: 65/67, Avg. train loss: 1097.640, time: 264.04, Avg. per iter 3.16, Est. time left 6.33
# Testing...
# gotcha
# Epoch: 15/250, Step: 5/71, Avg. test loss: 1312.796, time: 8.14, Avg. per iter 3.18, Est. time left 209.83
# Epoch: 15/250, Step: 10/71, Avg. test loss: 1300.470, time: 16.08, Avg. per iter 3.18, Est. time left 193.97
# Epoch: 15/250, Step: 15/71, Avg. test loss: 1314.434, time: 23.72, Avg. per iter 3.18, Est. time left 177.92
# Epoch: 15/250, Step: 20/71, Avg. test loss: 1311.244, time: 31.55, Avg. per iter 3.18, Est. time left 162.17
# Epoch: 15/250, Step: 25/71, Avg. test loss: 1314.804, time: 39.44, Avg. per iter 3.18, Est. time left 146.36
# Epoch: 15/250, Step: 30/71, Avg. test loss: 1313.630, time: 48.17, Avg. per iter 3.19, Est. time left 130.90
# Epoch: 15/250, Step: 35/71, Avg. test loss: 1322.311, time: 57.47, Avg. per iter 3.16, Est. time left 113.67
# Epoch: 15/250, Step: 40/71, Avg. test loss: 1333.110, time: 65.88, Avg. per iter 3.04, Est. time left 94.13
# Epoch: 15/250, Step: 45/71, Avg. test loss: 1336.271, time: 74.23, Avg. per iter 2.92, Est. time left 75.89
# Epoch: 15/250, Step: 50/71, Avg. test loss: 1334.712, time: 82.19, Avg. per iter 2.80, Est. time left 58.71
# Epoch: 15/250, Step: 55/71, Avg. test loss: 1327.372, time: 90.25, Avg. per iter 2.67, Est. time left 42.79
# Epoch: 15/250, Step: 60/71, Avg. test loss: 1324.465, time: 98.24, Avg. per iter 2.55, Est. time left 28.06
# Epoch: 15/250, Step: 65/71, Avg. test loss: 1327.641, time: 106.18, Avg. per iter 2.43, Est. time left 14.57
# Epoch: 15/250, Step: 70/71, Avg. test loss: 1326.333, time: 114.12, Avg. per iter 2.31, Est. time left 2.31
# Epoch: 15, Training loss: 1080.485, Test loss: 1314.973
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data97.tfrecords']
# Iterating length... 	Done: 67
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data198.tfrecords']
# Iterating length... 	Done: 66
# Training...
# gotcha
# Epoch: 16/250, Step: 5/67, Avg. train loss: 1109.003, time: 21.94, Avg. per iter 2.29, Est. time left 141.83
# Epoch: 16/250, Step: 10/67, Avg. train loss: 1071.956, time: 44.90, Avg. per iter 2.31, Est. time left 131.80
# Epoch: 16/250, Step: 15/67, Avg. train loss: 1070.919, time: 65.83, Avg. per iter 2.32, Est. time left 120.55
# Epoch: 16/250, Step: 20/67, Avg. train loss: 1063.918, time: 86.81, Avg. per iter 2.33, Est. time left 109.34
# Epoch: 16/250, Step: 25/67, Avg. train loss: 1083.038, time: 107.39, Avg. per iter 2.33, Est. time left 97.86
# Epoch: 16/250, Step: 30/67, Avg. train loss: 1077.818, time: 127.89, Avg. per iter 2.38, Est. time left 88.24
# Epoch: 16/250, Step: 35/67, Avg. train loss: 1094.852, time: 151.34, Avg. per iter 2.54, Est. time left 81.33
# Epoch: 16/250, Step: 40/67, Avg. train loss: 1099.558, time: 173.65, Avg. per iter 2.68, Est. time left 72.48
# Epoch: 16/250, Step: 45/67, Avg. train loss: 1088.893, time: 198.23, Avg. per iter 2.85, Est. time left 62.80
# Epoch: 16/250, Step: 50/67, Avg. train loss: 1087.945, time: 221.07, Avg. per iter 3.00, Est. time left 51.07
# Epoch: 16/250, Step: 55/67, Avg. train loss: 1090.996, time: 245.10, Avg. per iter 3.16, Est. time left 37.93
# ...
# Epoch: 240/250, Step: 30/66, Avg. test loss: 1100.424, time: 50.58, Avg. per iter 3.36, Est. time left 120.93
# Epoch: 240/250, Step: 35/66, Avg. test loss: 1090.500, time: 58.77, Avg. per iter 3.33, Est. time left 103.24
# Epoch: 240/250, Step: 40/66, Avg. test loss: 1084.418, time: 66.94, Avg. per iter 3.19, Est. time left 83.00
# Epoch: 240/250, Step: 45/66, Avg. test loss: 1091.056, time: 75.05, Avg. per iter 3.06, Est. time left 64.24
# Epoch: 240/250, Step: 50/66, Avg. test loss: 1085.531, time: 83.08, Avg. per iter 2.92, Est. time left 46.79
# Epoch: 240/250, Step: 55/66, Avg. test loss: 1080.078, time: 91.22, Avg. per iter 2.78, Est. time left 30.59
# Epoch: 240/250, Step: 60/66, Avg. test loss: 1085.590, time: 99.27, Avg. per iter 2.62, Est. time left 15.73
# Epoch: 240/250, Step: 65/66, Avg. test loss: 1091.524, time: 107.14, Avg. per iter 2.48, Est. time left 2.48
# Epoch: 240, Training loss: 1103.793, Test loss: 1077.944
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data98.tfrecords']
# Iterating length... 	Done: 63
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data199.tfrecords']
# Iterating length... 	Done: 70
# Training...
# gotcha
# Epoch: 241/250, Step: 5/63, Avg. train loss: 873.371, time: 21.71, Avg. per iter 2.45, Est. time left 141.86
# Epoch: 241/250, Step: 10/63, Avg. train loss: 895.292, time: 43.44, Avg. per iter 2.45, Est. time left 130.01
# Epoch: 241/250, Step: 15/63, Avg. train loss: 922.374, time: 64.86, Avg. per iter 2.45, Est. time left 117.77
# Epoch: 241/250, Step: 20/63, Avg. train loss: 907.972, time: 85.14, Avg. per iter 2.45, Est. time left 105.17
# Epoch: 241/250, Step: 25/63, Avg. train loss: 896.353, time: 105.47, Avg. per iter 2.44, Est. time left 92.78
# Epoch: 241/250, Step: 30/63, Avg. train loss: 873.812, time: 125.56, Avg. per iter 2.43, Est. time left 80.34
# Epoch: 241/250, Step: 35/63, Avg. train loss: 883.839, time: 145.55, Avg. per iter 2.49, Est. time left 69.73
# Epoch: 241/250, Step: 40/63, Avg. train loss: 881.195, time: 165.62, Avg. per iter 2.61, Est. time left 59.98
# Epoch: 241/250, Step: 45/63, Avg. train loss: 878.389, time: 186.55, Avg. per iter 2.74, Est. time left 49.24
# Epoch: 241/250, Step: 50/63, Avg. train loss: 879.337, time: 207.40, Avg. per iter 2.86, Est. time left 37.21
# Epoch: 241/250, Step: 55/63, Avg. train loss: 881.058, time: 228.78, Avg. per iter 2.99, Est. time left 23.94
# Epoch: 241/250, Step: 60/63, Avg. train loss: 873.664, time: 248.71, Avg. per iter 3.11, Est. time left 9.32
# Testing...
# gotcha
# Epoch: 241/250, Step: 5/70, Avg. test loss: 1005.373, time: 8.08, Avg. per iter 3.15, Est. time left 204.55
# Epoch: 241/250, Step: 10/70, Avg. test loss: 1001.524, time: 15.75, Avg. per iter 3.14, Est. time left 188.49
# Epoch: 241/250, Step: 15/70, Avg. test loss: 983.549, time: 23.53, Avg. per iter 3.14, Est. time left 172.61
# Epoch: 241/250, Step: 20/70, Avg. test loss: 986.108, time: 31.44, Avg. per iter 3.14, Est. time left 156.84
# Epoch: 241/250, Step: 25/70, Avg. test loss: 986.169, time: 39.19, Avg. per iter 3.13, Est. time left 141.01
# Epoch: 241/250, Step: 30/70, Avg. test loss: 988.578, time: 46.84, Avg. per iter 3.13, Est. time left 125.17
# Epoch: 241/250, Step: 35/70, Avg. test loss: 985.096, time: 54.47, Avg. per iter 3.13, Est. time left 109.42
# Epoch: 241/250, Step: 40/70, Avg. test loss: 994.879, time: 62.03, Avg. per iter 3.05, Est. time left 91.61
# Epoch: 241/250, Step: 45/70, Avg. test loss: 991.649, time: 69.69, Avg. per iter 2.92, Est. time left 72.94
# Epoch: 241/250, Step: 50/70, Avg. test loss: 1001.355, time: 77.25, Avg. per iter 2.77, Est. time left 55.43
# Epoch: 241/250, Step: 55/70, Avg. test loss: 1013.552, time: 84.85, Avg. per iter 2.64, Est. time left 39.65
# Epoch: 241/250, Step: 60/70, Avg. test loss: 1016.883, time: 92.39, Avg. per iter 2.52, Est. time left 25.16
# Epoch: 241/250, Step: 65/70, Avg. test loss: 1029.457, time: 100.03, Avg. per iter 2.39, Est. time left 11.95
# Epoch: 241/250, Step: 70/70, Avg. test loss: 1018.925, time: 106.83, Avg. per iter 2.26, Est. time left 0.00
# Epoch: 241, Training loss: 863.090, Test loss: 1018.925
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data115.tfrecords']
# Iterating length... 	Done: 70
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data191.tfrecords']
# Iterating length... 	Done: 66
# Training...
# gotcha
# Epoch: 242/250, Step: 5/70, Avg. train loss: 975.706, time: 20.16, Avg. per iter 2.26, Est. time left 146.62
# Epoch: 242/250, Step: 10/70, Avg. train loss: 929.310, time: 40.06, Avg. per iter 2.25, Est. time left 134.73
# Epoch: 242/250, Step: 15/70, Avg. train loss: 929.876, time: 59.85, Avg. per iter 2.24, Est. time left 123.39
# Epoch: 242/250, Step: 20/70, Avg. train loss: 926.461, time: 79.54, Avg. per iter 2.22, Est. time left 110.92
# Epoch: 242/250, Step: 25/70, Avg. train loss: 942.757, time: 99.18, Avg. per iter 2.21, Est. time left 99.66
# Epoch: 242/250, Step: 30/70, Avg. train loss: 961.041, time: 118.84, Avg. per iter 2.24, Est. time left 89.43
# Epoch: 242/250, Step: 35/70, Avg. train loss: 960.690, time: 138.41, Avg. per iter 2.35, Est. time left 82.37
# Epoch: 242/250, Step: 40/70, Avg. train loss: 961.200, time: 158.11, Avg. per iter 2.47, Est. time left 74.21
# Epoch: 242/250, Step: 45/70, Avg. train loss: 970.225, time: 178.39, Avg. per iter 2.60, Est. time left 64.96
# Epoch: 242/250, Step: 50/70, Avg. train loss: 972.984, time: 198.06, Avg. per iter 2.72, Est. time left 54.33
# Epoch: 242/250, Step: 55/70, Avg. train loss: 967.872, time: 217.70, Avg. per iter 2.84, Est. time left 42.53
# Epoch: 242/250, Step: 60/70, Avg. train loss: 975.810, time: 237.37, Avg. per iter 2.96, Est. time left 29.56
# Epoch: 242/250, Step: 65/70, Avg. train loss: 971.644, time: 256.99, Avg. per iter 3.08, Est. time left 15.38
# Epoch: 242/250, Step: 70/70, Avg. train loss: 968.102, time: 275.19, Avg. per iter 3.18, Est. time left 0.00
# Testing...
# gotcha
# Epoch: 242/250, Step: 5/66, Avg. test loss: 1140.049, time: 7.83, Avg. per iter 3.18, Est. time left 194.01
# Epoch: 242/250, Step: 10/66, Avg. test loss: 1149.109, time: 16.15, Avg. per iter 3.19, Est. time left 178.52
# Epoch: 242/250, Step: 15/66, Avg. test loss: 1106.636, time: 23.68, Avg. per iter 3.19, Est. time left 162.55
# Epoch: 242/250, Step: 20/66, Avg. test loss: 1112.384, time: 31.22, Avg. per iter 3.19, Est. time left 146.61
# Epoch: 242/250, Step: 25/66, Avg. test loss: 1077.119, time: 38.71, Avg. per iter 3.19, Est. time left 130.62
# Epoch: 242/250, Step: 30/66, Avg. test loss: 1059.407, time: 46.29, Avg. per iter 3.19, Est. time left 114.97
# Epoch: 242/250, Step: 35/66, Avg. test loss: 1079.443, time: 53.94, Avg. per iter 3.07, Est. time left 95.20
# Epoch: 242/250, Step: 40/66, Avg. test loss: 1078.934, time: 61.64, Avg. per iter 2.95, Est. time left 76.67
# Epoch: 242/250, Step: 45/66, Avg. test loss: 1062.910, time: 69.19, Avg. per iter 2.83, Est. time left 59.36
# Epoch: 242/250, Step: 50/66, Avg. test loss: 1061.356, time: 76.79, Avg. per iter 2.71, Est. time left 43.29
# Epoch: 242/250, Step: 55/66, Avg. test loss: 1058.154, time: 84.41, Avg. per iter 2.59, Est. time left 28.44
# Epoch: 242/250, Step: 60/66, Avg. test loss: 1058.464, time: 91.96, Avg. per iter 2.46, Est. time left 14.79
# Epoch: 242/250, Step: 65/66, Avg. test loss: 1059.363, time: 99.57, Avg. per iter 2.34, Est. time left 2.34
# Epoch: 242, Training loss: 968.102, Test loss: 1052.849
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data178.tfrecords']
# Iterating length... 	Done: 62
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data197.tfrecords']
# Iterating length... 	Done: 71
# Training...
# gotcha
# Epoch: 243/250, Step: 5/62, Avg. train loss: 1042.960, time: 20.43, Avg. per iter 2.32, Est. time left 132.24
# Epoch: 243/250, Step: 10/62, Avg. train loss: 1073.577, time: 40.13, Avg. per iter 2.31, Est. time left 120.29
# Epoch: 243/250, Step: 15/62, Avg. train loss: 1041.742, time: 59.75, Avg. per iter 2.31, Est. time left 108.75
# Epoch: 243/250, Step: 20/62, Avg. train loss: 1035.032, time: 79.46, Avg. per iter 2.31, Est. time left 97.17
# Epoch: 243/250, Step: 25/62, Avg. train loss: 1035.852, time: 99.17, Avg. per iter 2.31, Est. time left 85.63
# Epoch: 243/250, Step: 30/62, Avg. train loss: 1023.175, time: 118.85, Avg. per iter 2.31, Est. time left 74.01
# Epoch: 243/250, Step: 35/62, Avg. train loss: 1020.981, time: 138.54, Avg. per iter 2.35, Est. time left 63.56
# Epoch: 243/250, Step: 40/62, Avg. train loss: 1012.534, time: 158.99, Avg. per iter 2.48, Est. time left 54.61
# Epoch: 243/250, Step: 45/62, Avg. train loss: 1017.415, time: 178.99, Avg. per iter 2.60, Est. time left 44.20
# Epoch: 243/250, Step: 50/62, Avg. train loss: 1013.413, time: 199.56, Avg. per iter 2.73, Est. time left 32.76
# Epoch: 243/250, Step: 55/62, Avg. train loss: 995.329, time: 220.36, Avg. per iter 2.86, Est. time left 20.04
# Epoch: 243/250, Step: 60/62, Avg. train loss: 998.139, time: 241.03, Avg. per iter 2.99, Est. time left 5.99
# Testing...
# gotcha
# Epoch: 243/250, Step: 5/71, Avg. test loss: 1090.994, time: 9.05, Avg. per iter 3.05, Est. time left 201.57
# Epoch: 243/250, Step: 10/71, Avg. test loss: 1065.972, time: 17.27, Avg. per iter 3.06, Est. time left 186.59
# Epoch: 243/250, Step: 15/71, Avg. test loss: 1079.859, time: 26.44, Avg. per iter 3.07, Est. time left 172.20
# Epoch: 243/250, Step: 20/71, Avg. test loss: 1066.270, time: 35.26, Avg. per iter 3.09, Est. time left 157.44
# Epoch: 243/250, Step: 25/71, Avg. test loss: 1093.710, time: 45.51, Avg. per iter 3.11, Est. time left 143.22
# Epoch: 243/250, Step: 30/71, Avg. test loss: 1091.580, time: 53.57, Avg. per iter 3.12, Est. time left 127.84
# Epoch: 243/250, Step: 35/71, Avg. test loss: 1108.824, time: 61.51, Avg. per iter 3.12, Est. time left 112.39
# Epoch: 243/250, Step: 40/71, Avg. test loss: 1114.392, time: 69.46, Avg. per iter 3.08, Est. time left 95.50
# Epoch: 243/250, Step: 45/71, Avg. test loss: 1112.444, time: 77.74, Avg. per iter 2.96, Est. time left 77.06
# Epoch: 243/250, Step: 50/71, Avg. test loss: 1109.524, time: 85.63, Avg. per iter 2.85, Est. time left 59.78
# Epoch: 243/250, Step: 55/71, Avg. test loss: 1115.412, time: 94.03, Avg. per iter 2.73, Est. time left 43.73
# Epoch: 243/250, Step: 60/71, Avg. test loss: 1110.144, time: 102.13, Avg. per iter 2.62, Est. time left 28.79
# Epoch: 243/250, Step: 65/71, Avg. test loss: 1115.646, time: 110.24, Avg. per iter 2.50, Est. time left 15.01
# Epoch: 243/250, Step: 70/71, Avg. test loss: 1120.962, time: 119.29, Avg. per iter 2.40, Est. time left 2.40
# Epoch: 243, Training loss: 1002.854, Test loss: 1109.401
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/data151.tfrecords']
# Iterating length... 	Done: 69
# Loading tfrecords... 	['/home/patricknit/rl_data/tfrecord_wfiltered/test/data188.tfrecords']
# Iterating length... 	Done: 64
# Training...
# gotcha
# Epoch: 244/250, Step: 5/69, Avg. train loss: 848.377, time: 25.49, Avg. per iter 2.41, Est. time left 154.18
# Epoch: 244/250, Step: 10/69, Avg. train loss: 933.954, time: 48.04, Avg. per iter 2.43, Est. time left 143.66
# Epoch: 244/250, Step: 15/69, Avg. train loss: 916.032, time: 69.76, Avg. per iter 2.45, Est. time left 132.50
# Epoch: 244/250, Step: 20/69, Avg. train loss: 947.707, time: 91.20, Avg. per iter 2.46, Est. time left 120.30
# Epoch: 244/250, Step: 25/69, Avg. train loss: 942.638, time: 112.08, Avg. per iter 2.46, Est. time left 108.10
# Epoch: 244/250, Step: 30/69, Avg. train loss: 928.098, time: 134.07, Avg. per iter 2.50, Est. time left 97.36
# Epoch: 244/250, Step: 35/69, Avg. train loss: 918.669, time: 156.53, Avg. per iter 2.64, Est. time left 89.65
# Epoch: 244/250, Step: 40/69, Avg. train loss: 913.915, time: 177.84, Avg. per iter 2.77, Est. time left 80.19
# Epoch: 244/250, Step: 45/69, Avg. train loss: 910.820, time: 198.76, Avg. per iter 2.88, Est. time left 69.21
# Epoch: 244/250, Step: 50/69, Avg. train loss: 920.771, time: 219.43, Avg. per iter 3.00, Est. time left 56.96
# Epoch: 244/250, Step: 55/69, Avg. train loss: 922.750, time: 240.31, Avg. per iter 3.11, Est. time left 43.53
# Epoch: 244/250, Step: 60/69, Avg. train loss: 926.318, time: 262.07, Avg. per iter 3.25, Est. time left 29.24
# Epoch: 244/250, Step: 65/69, Avg. train loss: 937.809, time: 284.02, Avg. per iter 3.39, Est. time left 13.55
# Testing...
# gotcha
# Epoch: 244/250, Step: 5/64, Avg. test loss: 997.770, time: 9.47, Avg. per iter 3.47, Est. time left 204.90
# Epoch: 244/250, Step: 10/64, Avg. test loss: 992.268, time: 18.47, Avg. per iter 3.48, Est. time left 188.14
# Epoch: 244/250, Step: 15/64, Avg. test loss: 1009.383, time: 27.80, Avg. per iter 3.49, Est. time left 171.17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <module>
#      64 optimiser.zero_grad()
#      66 # VAE forward pass
# ---> 67 x_hat, mu, logvar, z = vae_model(image)
#      69 # Loss
#      70 loss = filtered_weighted_MSE(image_filtered, x_hat, mu, logvar)
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# Input In [9], in VAE.forward(self, x)
#      22 def forward(self, x):
# ---> 24     x = self.q_img(x)
#      26     means = self.mean_params(x)
#      27     logvar = self.logvar_params(x)
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# Input In [7], in Dronet.forward(self, img)
#      61 x2 = self.bn0(x1)
#      62 x2 = torch.relu(x2)
# ---> 63 x2 = self.conv1(x2)
#      65 x2 = self.bn1(x2)
#      66 x2 = torch.relu(x2)
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/torch/nn/modules/conv.py:446, in Conv2d.forward(self, input)
#     445 def forward(self, input: Tensor) -> Tensor:
# --> 446     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/torch/nn/modules/conv.py:442, in Conv2d._conv_forward(self, input, weight, bias)
#     438 if self.padding_mode != 'zeros':
#     439     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     440                     weight, bias, self.stride,
#     441                     _pair(0), self.dilation, self.groups)
# --> 442 return F.conv2d(input, weight, bias, self.stride,
#     443                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %% [markdown]
# # Evaluation

# %%
load_model_file = base_path + "/vae_models/vae_dronet_sigmoid_MSE_weighted_filtered_140.pth"
load_model=False

if load_model:
    vae_model.load_state_dict(torch.load(load_model_file))

# %%
vae_model.eval()

# Visualise sample of images
with torch.no_grad():
    images, filtered, *_ = next(iter(test_loader))
    x_hat, *_ = vae_model.forward_test(images)

    print(images.mean(), filtered.mean(), x_hat.mean())
    print(images.var(), filtered.var(), x_hat.var())

    gridshow([images, filtered, x_hat], n_grids=batch_size)
# Out:
# gotcha
# tensor(0.4692) tensor(0.4213) tensor(0.3766)
# tensor(0.1097) tensor(0.0989) tensor(0.0764)

# %%
train_dataset = DepthImageDataset(tfrecord_folder=tfrecord_folder, batch_size=batch_size, one_tfrecord=True) # load new tfrecord each time
train_loader = DataLoader(dataset=train_dataset, batch_size=1, collate_fn=collate_batch)

vae_model.eval()

with torch.no_grad():
    images, filtered, *_ = next(iter(train_loader))
    x_hat, *_ = vae_model.forward_test(images)

    print(images.mean(), filtered.mean(), x_hat.mean())
    print(images.var(), filtered.var(), x_hat.var())

    gridshow([images, filtered, x_hat], n_grids=batch_size)
