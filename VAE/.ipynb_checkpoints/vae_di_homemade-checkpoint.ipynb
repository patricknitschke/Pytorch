# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
from torch.optim import Adam
import torchvision.transforms.functional as fn

import os
import time
import math
import numpy as np
import matplotlib.pyplot as plt

from di_dataset import DepthImageDataset

from torch.utils.tensorboard import SummaryWriter

# %%
writer = SummaryWriter('runs/vae_cifar10')

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# 2022-02-24 14:37:13.632209: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# cpu
# /home/patricknit/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/torch/cuda/__init__.py:80: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 10010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:112.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# # Load Dataset

# %%
saves_folders = "../../../rl_data"
load_paths = [os.path.join(saves_folders, saves_folder) for saves_folder in os.listdir(saves_folders)]

# %%
load_path = "../../../rl_data/saves_2"

# %%
# Hyperparams
latent_dim = 100 
num_epochs = 10
batch_size = 1
learning_rate = 1e-3

# %%
# Obtain train and test data
dataset = DepthImageDataset(load_path=load_path) # Can only do 1 pickle file for now
# Out:
# Loading from ../../../rl_data/saves_2
# 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.43it/s]

# %%
train_size = int(0.9 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, num_workers=0)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, num_workers=0)
len(train_loader), len(test_loader), len(train_dataset), len(test_dataset)
# Out:
# (19, 3, 19, 3)

# %%
dataiter = iter(train_loader)
image_batch = dataiter.next()

def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

for image in image_batch:
    imshow(image)
    
image.shape
# Out:
# torch.Size([1, 272, 480])

# %%
image_batch.squeeze().mean(), image_batch.squeeze().var()
# Out:
# (tensor(0.6234), tensor(0.1427))

# %% [markdown]
# # Define Variational Autoencoder

# %%
class VAE(nn.Module):
    def __init__(self, input_channels, feature_dim=31*57, latent_dim=500) -> None:
        super(VAE, self).__init__()
        # (input width - filter size + 2*padding)/stride + 1
        self.encoder = nn.Sequential(
            nn.Conv2d(input_channels, 16, kernel_size=5, stride=2),
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=5, stride=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=5, stride=2),
            nn.ReLU()
        )
        
        self.fc_mu = nn.Linear(64*feature_dim, latent_dim)
        self.fc_logvar = nn.Linear(64*feature_dim, latent_dim)
        
        self.fc_z = nn.Linear(latent_dim, 64*feature_dim)
        
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size=5, stride=2),
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=5, stride=2, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(16, input_channels, kernel_size=5, stride=2, output_padding=1),
            nn.ReLU(),
            nn.Sigmoid()
        )

    def forward(self, x):
        # Inference
        x_enc = self.encoder(x)
        x_enc = x_enc.view(-1, 64*31*57)
        
        mu = self.fc_mu(x_enc)
        logvar = self.fc_logvar(x_enc)

        # Reparametrisation
        std = torch.exp(logvar/2)
        epsilon = torch.randn_like(std) # generate eps [0,1) with dim matching std
        z = mu + std * epsilon

        # Generate
        x_hat = self.fc_z(z)
        x_hat = x_hat.view(-1, 64, 31, 57)
        x_hat = self.decoder(x_hat)
        
        return mu, logvar, x_hat
    
vae_model = VAE(input_channels=1, latent_dim=latent_dim)

# %%
from torchsummary import summary
summary(vae_model, (1, 272, 480))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 134, 238]             416
#               ReLU-2         [-1, 16, 134, 238]               0
#             Conv2d-3          [-1, 32, 65, 117]          12,832
#               ReLU-4          [-1, 32, 65, 117]               0
#             Conv2d-5           [-1, 64, 31, 57]          51,264
#               ReLU-6           [-1, 64, 31, 57]               0
#             Linear-7                  [-1, 100]      11,308,900
#             Linear-8                  [-1, 100]      11,308,900
#             Linear-9               [-1, 113088]      11,421,888
#   ConvTranspose2d-10          [-1, 32, 65, 117]          51,232
#              ReLU-11          [-1, 32, 65, 117]               0
#   ConvTranspose2d-12         [-1, 16, 134, 238]          12,816
#              ReLU-13         [-1, 16, 134, 238]               0
#   ConvTranspose2d-14          [-1, 1, 272, 480]             401
#              ReLU-15          [-1, 1, 272, 480]               0
#           Sigmoid-16          [-1, 1, 272, 480]               0
# ================================================================
# Total params: 34,168,649
# Trainable params: 34,168,649
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.50
# Forward/backward pass size (MB): 28.58
# Params size (MB): 130.34
# Estimated Total Size (MB): 159.42
# ----------------------------------------------------------------

# %% [markdown]
# # Training

# %%
def loss_function(x, x_hat, mean, log_var):
    #reproduction_loss = nn.BCELoss(reduction='sum')(x_hat, x)
    reproduction_loss = F.binary_cross_entropy(x_hat, x, reduction="sum")
    KLD      = 0.5 * torch.sum(1+ log_var - mean.pow(2) - log_var.exp())

    return reproduction_loss - KLD

# %%
# def loss_function(x, x_hat, mu, logvar):
#     reproduction_loss = F.mse_loss(x_hat, x, reduction="sum")
#     kl_divergence = 0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

#     return reproduction_loss - kl_divergence

# %%
n_training_samples = len(train_dataset)
n_iterations = math.ceil(n_training_samples/batch_size)
n_training_samples, n_iterations
# Out:
# (19, 19)

# %%
vae_model = VAE(input_channels=1, latent_dim=latent_dim)
optimiser = torch.optim.Adam(vae_model.parameters(), lr=learning_rate)

# %%
for epoch in range(num_epochs):
    overall_loss = 0
    since = time.time()
    for i, image in enumerate(train_loader):

        optimiser.zero_grad()

        # VAE forward pass
        mu, logvar, x_hat = vae_model(image)

        # Loss
        loss = loss_function(image, x_hat, mu, logvar)

        overall_loss += loss

        # Update weights
        loss.backward()
        optimiser.step()

        if (i+1) % 1 == 0:
            time_elapsed = time.time() - since
            #print(f"epoch: {epoch+1}/{num_epochs}, step: {i+1}/{n_iterations}, image: {image.shape}")
            print(f"epoch: {epoch+1}/{num_epochs}, step: {i+1}/{n_iterations}, Avg loss: {overall_loss/((i+1)*batch_size):.3f}, time: {time_elapsed:.3f}")
# Out:
# epoch: 1/10, step: 1/19, Avg loss: 90496.617, time: 0.548
# epoch: 1/10, step: 2/19, Avg loss: 90255.500, time: 0.952
# epoch: 1/10, step: 3/19, Avg loss: 239648.828, time: 1.368
# epoch: 1/10, step: 4/19, Avg loss: 202021.016, time: 1.771
# epoch: 1/10, step: 5/19, Avg loss: 179727.922, time: 2.211
# epoch: 1/10, step: 6/19, Avg loss: 164856.422, time: 2.677
# epoch: 1/10, step: 7/19, Avg loss: 154229.781, time: 2.995
# epoch: 1/10, step: 8/19, Avg loss: 146271.188, time: 3.350
# epoch: 1/10, step: 9/19, Avg loss: 140077.266, time: 3.708
# epoch: 1/10, step: 10/19, Avg loss: 135117.453, time: 4.075
# epoch: 1/10, step: 11/19, Avg loss: 131062.383, time: 4.370
# epoch: 1/10, step: 12/19, Avg loss: 127682.875, time: 4.717
# epoch: 1/10, step: 13/19, Avg loss: 124822.414, time: 5.048
# epoch: 1/10, step: 14/19, Avg loss: 122368.797, time: 5.371
# epoch: 1/10, step: 15/19, Avg loss: 120243.734, time: 5.816
# epoch: 1/10, step: 16/19, Avg loss: 118386.078, time: 6.270
# epoch: 1/10, step: 17/19, Avg loss: 116739.633, time: 6.837
# epoch: 1/10, step: 18/19, Avg loss: 115275.703, time: 7.260
# epoch: 1/10, step: 19/19, Avg loss: 113961.477, time: 7.673
# epoch: 2/10, step: 1/19, Avg loss: 90373.039, time: 0.347
# epoch: 2/10, step: 2/19, Avg loss: 89761.305, time: 0.715
# epoch: 2/10, step: 3/19, Avg loss: 89132.188, time: 1.058
# epoch: 2/10, step: 4/19, Avg loss: 88469.836, time: 1.469
            # show images
            imshow(images[idx])
            imshow(x_hat[idx])

        # write to tensorboard
        # writer.add_image('four_cifar10_images', inv_normalize(img_grid))
# Out:
# tensor(0.3983) tensor(0.5367)
# tensor(0.0252) tensor(0.0060)
# torch.Size([1, 1, 272, 480])
# tensor(0.3998) tensor(0.5301)
# tensor(0.0377) tensor(0.0052)
# torch.Size([1, 1, 272, 480])
# tensor(0.6234) tensor(0.5432)
# tensor(0.1427) tensor(0.0078)
# torch.Size([1, 1, 272, 480])

# %% [markdown]
# ## Training set

# %%
vae_model.eval()
# Visualise sample of images
with torch.no_grad():
    for images in train_loader:
        # VAE forward pass
        _, _, x_hat = vae_model(images)

        print(images.mean(), x_hat.mean())
        print(images.var(), x_hat.var())
        print(images.shape)
        for idx in range(1):
            # show images
            imshow(images[idx])
            imshow(x_hat[idx])
# Out:
# tensor(0.6234) tensor(0.6188)
# tensor(0.1427) tensor(0.0256)
# torch.Size([1, 1, 272, 480])
# tensor(0.7650) tensor(0.6727)
# tensor(0.0831) tensor(0.0341)
# torch.Size([1, 1, 272, 480])
# tensor(0.7258) tensor(0.6728)
# tensor(0.1035) tensor(0.0357)
# torch.Size([1, 1, 272, 480])
# tensor(0.7875) tensor(0.6701)
# tensor(0.0719) tensor(0.0318)
# torch.Size([1, 1, 272, 480])
# tensor(0.5920) tensor(0.6011)
# tensor(0.1035) tensor(0.0205)
# torch.Size([1, 1, 272, 480])
# tensor(0.7258) tensor(0.6657)
# tensor(0.1035) tensor(0.0380)
# torch.Size([1, 1, 272, 480])
# tensor(0.7420) tensor(0.6170)
# tensor(0.0769) tensor(0.0208)
# torch.Size([1, 1, 272, 480])
# tensor(0.3998) tensor(0.5255)
# tensor(0.0377) tensor(0.0044)
# torch.Size([1, 1, 272, 480])
# tensor(0.5193) tensor(0.6029)
# tensor(0.1359) tensor(0.0256)
# torch.Size([1, 1, 272, 480])
# tensor(0.7650) tensor(0.6561)
# tensor(0.0831) tensor(0.0338)
# torch.Size([1, 1, 272, 480])
# tensor(0.4983) tensor(0.5433)
# tensor(0.0856) tensor(0.0106)
# torch.Size([1, 1, 272, 480])
# tensor(0.3983) tensor(0.5241)
# tensor(0.0252) tensor(0.0041)
# torch.Size([1, 1, 272, 480])
# tensor(0.5920) tensor(0.5654)
# tensor(0.1035) tensor(0.0134)
# torch.Size([1, 1, 272, 480])
# tensor(0.7420) tensor(0.6162)
# tensor(0.0769) tensor(0.0187)
# torch.Size([1, 1, 272, 480])
# tensor(0.5193) tensor(0.5914)
# tensor(0.1359) tensor(0.0206)
# torch.Size([1, 1, 272, 480])
# tensor(0.4983) tensor(0.5474)
# tensor(0.0856) tensor(0.0113)
# torch.Size([1, 1, 272, 480])
# tensor(0.7407) tensor(0.6907)
# tensor(0.0962) tensor(0.0389)
# torch.Size([1, 1, 272, 480])
# tensor(0.7875) tensor(0.6608)
# tensor(0.0719) tensor(0.0295)
# torch.Size([1, 1, 272, 480])
# tensor(0.7407) tensor(0.6837)
# tensor(0.0962) tensor(0.0405)
# torch.Size([1, 1, 272, 480])
